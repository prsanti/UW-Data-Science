# %% [markdown]
# # Group Assignment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as sm
import scipy
#from scipy import stats
from statsmodels.graphics.regressionplots import plot_regress_exog, plot_fit, plot_leverage_resid2, influence_plot

# %%
df = pd.read_csv('36100232.csv')

# %%
df.tail(15)
# Out:
#      REF_DATE     GEO           DGUID  Seasonal adjustment  \
# 4045  2022-04  Canada  2016A000011124           Unadjusted
# 4046  2022-04  Canada  2016A000011124           Unadjusted
# 4047  2022-04  Canada  2016A000011124           Unadjusted
# 4048  2022-04  Canada  2016A000011124           Unadjusted
# 4049  2022-04  Canada  2016A000011124  Seasonally adjusted
# 4050  2022-04  Canada  2016A000011124  Seasonally adjusted
# 4051  2022-04  Canada  2016A000011124  Seasonally adjusted
# 4052  2022-04  Canada  2016A000011124  Seasonally adjusted
# 4053  2022-04  Canada  2016A000011124  Seasonally adjusted
# 4054  2022-04  Canada  2016A000011124  Seasonally adjusted
# 4055  2022-04  Canada  2016A000011124  Seasonally adjusted
# 4056  2022-04  Canada  2016A000011124  Seasonally adjusted
# 4057  2022-04  Canada  2016A000011124  Seasonally adjusted
# 4058  2022-04  Canada  2016A000011124  Seasonally adjusted
# 4059  2022-04  Canada  2016A000011124  Seasonally adjusted
#
#                         Activities   UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID  \
# 4045      Other tourism activities  Jobs     190     thousands          3
# 4046  Recreation and entertainment  Jobs     190     thousands          3
# 4047               Travel agencies  Jobs     190     thousands          3
# 4048              Other industries  Jobs     190     thousands          3
# 4049            Tourism activities  Jobs     190     thousands          3
# 4050      Total tourism industries  Jobs     190     thousands          3
# 4051                Transportation  Jobs     190     thousands          3
# 4052            Air transportation  Jobs     190     thousands          3
# 4053          Other transportation  Jobs     190     thousands          3
# 4054                 Accommodation  Jobs     190     thousands          3
# 4055    Food and beverage services  Jobs     190     thousands          3
# 4056      Other tourism activities  Jobs     190     thousands          3
# 4057  Recreation and entertainment  Jobs     190     thousands          3
# 4058               Travel agencies  Jobs     190     thousands          3
# 4059              Other industries  Jobs     190     thousands          3
#
#          VECTOR COORDINATE  VALUE  STATUS  SYMBOL TERMINATED  DECIMALS
# 4045     v81684     1.1.12  100.6     NaN     NaN        NaN         1
# 4046     v81685     1.1.13   70.0     NaN     NaN        NaN         1
# 4047     v81686     1.1.14   30.6     NaN     NaN        NaN         1
# 4048     v81687     1.1.15  121.8     NaN     NaN        NaN         1
# 4049     v81658      1.2.1  621.5     NaN     NaN        NaN         1
# 4050     v81659      1.2.2  500.5     NaN     NaN        NaN         1
# 4051     v81660      1.2.3   65.0     NaN     NaN        NaN         1
# 4052     v81661      1.2.4   42.6     NaN     NaN        NaN         1
# 4053  v64605557     1.2.17   22.4     NaN     NaN        NaN         1
# 4054     v81667     1.2.10  120.6     NaN     NaN        NaN         1
# 4055     v81668     1.2.11  216.5     NaN     NaN        NaN         1
# 4056     v81669     1.2.12   98.4     NaN     NaN        NaN         1
# 4057     v81670     1.2.13   67.8     NaN     NaN        NaN         1
# 4058     v81671     1.2.14   30.6     NaN     NaN        NaN         1
# 4059     v81672     1.2.15  121.0     NaN     NaN        NaN         1
