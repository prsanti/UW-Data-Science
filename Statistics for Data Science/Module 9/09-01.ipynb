# %% [markdown]
# # Module 9: Time Series Analysis

# %% [markdown]
# # Introduction

# %% [markdown]
# Time series analysis is closely related to regression analysis. In time series analysis, the independent variable $x$ is always time. In this module, we will cover the most common techniques for analysis and forecasting of time series.

# %% [markdown]
# # Learning Outcomes

# %% [markdown]
# In this module, you will:
#
# * Gain familiarity with the concepts of time series
# * Explore basic methods of analysis of time series
# * Learn how to forecast a time series

# %% [markdown]
# # Reading and Resources

# %% [markdown]
# We invite you to further supplement this notebook with the following recommended texts:
#
#  - Hyndman, R.J. & Athanasopoulos, G. (2018). *Forecasting: Principles and Practice.* OTexts. https://www.datasciencecentral.com/group/resources/forum/topics/free-book-forecasting-principles-and-practice
#
#
#  - Bisgaard, S. & Kulahci, M. (2011). *Time series analysis and forecasting by example.* John Wiley & Sons. https://www.wiley.com/en-us/Time+Series+Analysis+and+Forecasting+by+Example-p-9780470540640

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <br>
# <div class="toc">
# <ul class="toc-item">
# <li><span><a href="#Module-9:-Time-Series-Analysis" data-toc-modified-id="Module-9:-Time-Series-Analysis">Module 9: Time Series Analysis</a></span>
# </li>
# <li><span><a href="#Introduction" data-toc-modified-id="Introduction">Introduction</a></span>
# </li>
# <li><span><a href="#Learning-Outcomes" data-toc-modified-id="Learning-Outcomes">Learning Outcomes</a></span>
# </li>
# <li><span><a href="#Reading-and-Resources" data-toc-modified-id="Reading-and-Resources">Reading and Resources</a></span>
# </li>
# <li><span><a href="#Table-of-Contents" data-toc-modified-id="Table-of-Contents">Table of Contents</a></span>
# </li>
# <li><span><a href="#Time-Series" data-toc-modified-id="Time-Series">Time Series</a></span>
# </li>
# <li><span><a href="#Techniques-of-Time-Series-Analysis" data-toc-modified-id="Techniques-of-Time-Series-Analysis">Techniques of Time Series Analysis</a></span>
# <ul class="toc-item">
# <li><span><a href="#Smoothing-of-the-Time-Series" data-toc-modified-id="Smoothing-of-the-Time-Series">Smoothing of the Time Series</a></span>
# <ul class="toc-item">
# <li><span><a href="#Simple-moving-average" data-toc-modified-id="Simple-moving-average">Simple moving average</a></span>
# </li>
# <li><span><a href="#Exponential-moving-average" data-toc-modified-id="Exponential-moving-average">Exponential moving average</a></span>
# <ul class="toc-item">
# <li><span><a href="#Analogy-between-EMA-and-SMA" data-toc-modified-id="Analogy-between-EMA-and-SMA">Analogy between EMA and SMA</a></span>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li><span><a href="#Autocorrelation-Analysis" data-toc-modified-id="Autocorrelation-Analysis">Autocorrelation Analysis</a></span>
# <ul class="toc-item">
# <li><span><a href="#Properties-of-autocorrelation" data-toc-modified-id="Properties-of-autocorrelation">Properties of autocorrelation</a></span>
# </li>
# <li><span><a href="#How-to-estimate-autocorrelation" data-toc-modified-id="How-to-estimate-autocorrelation">How to estimate autocorrelation</a></span>
# </li>
# <li><span><a href="#Partial-autocorrelation" data-toc-modified-id="Partial-autocorrelation">Partial autocorrelation</a></span>
# </li>
# <li><span><a href="#Correlogram" data-toc-modified-id="Correlogram">Correlogram</a></span>
# </li>
# </ul>
# </li>
# <li><span><a href="#Time-Series-Decomposition" data-toc-modified-id="Time-Series-Decomposition">Time Series Decomposition</a></span>
# <ul class="toc-item">
# <li><span><a href="#When-to-use-additive-and-multiplicative-decomposition" data-toc-modified-id="When-to-use-additive-and-multiplicative-decomposition">When to use additive and multiplicative decomposition</a></span>
# </li>
# <li><span><a href="#Seasonality-adjusted-time-series" data-toc-modified-id="Seasonality-adjusted-time-series">Seasonality adjusted time series</a></span>
# </li>
# <li><span><a href="#Measuring-the-strength-of-trend-and-seasonality" data-toc-modified-id="Measuring-the-strength-of-trend-and-seasonality">Measuring the strength of trend and seasonality</a></span>
# </li>
# </ul>
# </li>
# <li><span><a href="#Modelling-of-Time-Series-and-Forecasting" data-toc-modified-id="Modelling-of-Time-Series-and-Forecasting">Modelling of Time Series and Forecasting</a></span>
# <ul class="toc-item">
# <li><span><a href="#Autoregression-models" data-toc-modified-id="Autoregression-models">Autoregression models</a></span>
# <ul class="toc-item">
# <li><span><a href="#The-choice-of-the-maximum-lag" data-toc-modified-id="The-choice-of-the-maximum-lag">The choice of the maximum lag</a></span>
# </li>
# </ul>
# </li>
# <li><span><a href="#Moving-average-model" data-toc-modified-id="Moving-average-model">Moving average model</a></span>
# <ul class="toc-item">
# <li><span><a href="#A-few-important-notes-about-the-moving-average-model" data-toc-modified-id="A-few-important-notes-about-the-moving-average-model">A few important notes about the moving average model</a></span>
# </li>
# <li><span><a href="#The-choice-of-the-maximum-lag" data-toc-modified-id="The-choice-of-the-maximum-lag">The choice of the maximum lag</a></span>
# </li>
# </ul>
# </li>
# <li><span><a href="#Autoregressive-moving-average-(ARMA)-model-(and-its-extensions)" data-toc-modified-id="Autoregressive-moving-average-(ARMA)-model-(and-its-extensions)">Autoregressive moving average (ARMA) model (and its extensions)</a></span>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li><span><a href="#Long-term-Predictions" data-toc-modified-id="Long-term-Predictions">Long-term Predictions</a></span>
# <ul class="toc-item">
# <li><span><a href="#Word-of-caution-with-long-term-predictions" data-toc-modified-id="Word-of-caution-with-long-term-predictions">Word of caution with long-term predictions</a></span>
# </li>
# </ul>
# </li>
# <li><span><a href="#References" data-toc-modified-id="References">References</a></span>
# </li>
# </ul>
# </div>

# %% [markdown]
# # Time Series

# %% [markdown]
# A **time series** is a set of observations at different points in time. A time series can have a **fixed frequency** of observations (e.g. monthly), or have an **irregular frequency** of observations (i.e. the data points are irregularly spaced in time, whenever data is available). In this module, we will only consider time series that are observed at regular intervals of time (e.g. hourly, daily, weekly, monthly, quarterly, annually). Hereafter, we will work with **discretized time** (i.e. we will treat time as a variable, whose value grows incrementally):
#
# $$t + 1 = t + \Delta t$$
#
#
# where $\Delta t$ is a **time step** (interval) at which observations of the time series, often referred to as **realizations**, are collected.
#
# Very often, we assume that a time series may involve certain periodicity (e.g. yearly period of flu incidence rates, daily period of temperatures, etc.). In these cases, it is important to specify the time series **frequency** &mdash; i.e. the number of observations within the presumed period.
#
# For example:
#
#   - The frequency of daily observations of data with yearly periodicity is $F = 365$
#
#
#   - The frequency of hourly observations of data with daily periodicity is $F = 24$
#
# **NOTE:** Proper analysis of time series requires at least two observations per period (i.e. frequency of observations $\geq 2$).

# %% [markdown]
# **EXERCISE 1**

# %% [markdown]
# 1.) Import the two time series datasets provided (`daily_births.csv`, `passengers.csv`):
#
#   - **Births**: The total daily number of female births in California recorded in the year 1959
#   - **Passengers**: The total monthly number of passengers of international airlines (in thousands) recorded across the span of years 1949 - 1960.
#
#
# 2.) Without looking at the data, answer the following questions:
#
#   - What is the frequency of both time series?
#   - Does either time series contain periodicity?
#   - Are the time series mostly increasing or decreasing?
#   - Which one of the two is noisier?
#
#
# 3.) Plot the data to confirm your answers to the questions above.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from random import randrange
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.graphics import tsaplots

# %%
# Load passenger data set and save to DataFrame
passengers = pd.read_csv('./module09/passengers.csv', 
                         header=0, 
                         index_col=0, 
                         parse_dates=True, 
                         sep=';')

# Load daily births data set and save to DataFrame
births = pd.read_csv('./module09/daily_births.csv', 
                     header=0, 
                     index_col=0, 
                     parse_dates=True, 
                     sep=',')

# %%
passengers.head()
# Out:
#             n_passengers
# month
# 1949-01-01           112
# 1949-02-01           118
# 1949-03-01           132
# 1949-04-01           129
# 1949-05-01           121

# %%
births.head()
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44

# %%
passengers.index.to_series().diff().value_counts()
# Out:
# 31 days    83
# 30 days    48
# 28 days     9
# 29 days     3
# Name: month, dtype: int64

# %% [markdown]
# births.index.to_series().diff().value_counts()

# %%
births.index.to_series().diff().value_counts()
# Out:
# 1 days    364
# Name: Date, dtype: int64

# %%
plt.plot(passengers.index, 
         passengers.n_passengers)
plt.xlabel('Time')
plt.ylabel('Passengers per month (thousands)')
# Out:
# Text(0, 0.5, 'Passengers per month (thousands)')

# %%
plt.plot(births.index, 
         births.Births)
plt.xlabel('Time')
plt.ylabel('Births per day')
# Out:
# Text(0, 0.5, 'Births per day')

# %% [markdown]
# **Solution**

# %% [markdown]
# First, we will import the libraries. Some of the libraries below will be used in subsequent exercises.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from random import randrange
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.graphics import tsaplots

# %%
# Load passenger data set and save to DataFrame
passengers = pd.read_csv('./module09/passengers.csv', 
                         header=0, 
                         index_col=0, 
                         parse_dates=True, 
                         sep=';')

# %%
# Load daily births data set and save to DataFrame
births = pd.read_csv('./module09/daily_births.csv', 
                     header=0, 
                     index_col=0, 
                     parse_dates=True, 
                     sep=',')

# %% [markdown]
# Let's take a look at the first 5 rows of each time series.

# %%
passengers.head()
# Out:
#             n_passengers
# month
# 1949-01-01           112
# 1949-02-01           118
# 1949-03-01           132
# 1949-04-01           129
# 1949-05-01           121

# %%
births.head()
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44

# %% [markdown]
# Let's check whether the time series are regular (i.e. whether the time between any two observations remains the same).

# %%
passengers.index.to_series().diff().value_counts()
# Out:
# 31 days    83
# 30 days    48
# 28 days     9
# 29 days     3
# Name: month, dtype: int64

# %%
births.index.to_series().diff().value_counts()
# Out:
# 1 days    364
# Name: Date, dtype: int64

# %% [markdown]
# As we can see, the `passengers` time series contains small irregularities caused by the unequal length of the calendar months.

# %% [markdown]
# Next, we will plot both time series.

# %%
plt.plot(passengers.index, 
         passengers.n_passengers)
plt.xlabel('Time')
plt.ylabel('Passengers per month (thousands)')
# Out:
# Text(0, 0.5, 'Passengers per month (thousands)')

# %%
plt.plot(births.index, 
         births.Births)
plt.xlabel('Time')
plt.ylabel('Births per day')
# Out:
# Text(0, 0.5, 'Births per day')

# %% [markdown]
# Now, we can answer the above questions:
#
# - The frequency of the `passengers` dataset is 12, corresponding to 12 observations within the period of one year
# - The frequency of the `births` dataset is 365, corresponding to 365 observations within the period of one year
# - The `passengers` series signal is clearly periodic, probably due to the seasonal changes in people's travelling habits
# - There is no obvious periodicity in the `births` time series, as expected
# - The `passengers` series signal is mostly growing, which probably reflects the global growth of air transportation during the given period of time
# - The `births` time series is clearly noisier

# %% [markdown]
# # Techniques of Time Series Analysis
#
# Time series can be subjected to various analyses. Typically, the objective is to obtain a better understanding of the underlying data generating process, or to predict future observations of the time series. The most common techniques used to analyse time series include:
#
#  - Smoothing of the time series
#  - Autocorrelation analysis
#  - Time series decomposition
#  - Modelling the time series and forecasting
#
# We will cover these techniques in the following sections.

# %% [markdown]
# ## Smoothing of the Time Series

# %% [markdown]
# **Smoothing** describes a variety of techniques used to reduce, or remove "noise" from a time series. The procedure typically involves calculation of some type of **moving average** (MA) and its subsequent subtraction from the original data, which effectively filters out the short-term fluctuations while preserving the long-term trends.

# %% [markdown]
# ### Simple moving average
#
# The most straightforward moving average for smoothing a time series is the **simple moving average** (SMA). The SMA of a signal $y$ at time $t$ is a mean calculated across the set of $k - 1$ consecutive realizations of $y$ preceding time $t$ and the realization at time $t$. Mathematically, this can be formulated as:
#
# $$\text{SMA}_y(t, k) = \frac{y_t + y_{t-1} + \ldots + y_{t- (k-1)}}{k}$$
#
#
# or, more compactly:
#
# $$\text{SMA}_y(t, k) = \frac{1}{k}\sum^{k-1}_{i=0}\,\, y_{t - i}$$
#
# where:
#
#   - $y_t$ is the realization of the time series $y$ at time $t$
#   - $\text{SMA}_y(t, k)$ is the SMA of the times series $y$ at time $t$
#   - the set of values $y_t, y_{t-1}, \ldots, y_{t- (k-1)}$ comprise the **window** of the moving average
#   - $k$ is the window size, sometimes referred to as the **order** of the MA
#
# The smoothed signal $y\prime$ is produced from the original time series $y$ by applying the SMA:
#
# $$y_t\prime = \text{SMA}_y(t, k)$$
#
#
# The size of the window determines "how much" of the signal is to be removed. The bigger the window size, the larger the fluctuations that will be filtered out and the smoother the resulting signal will be.

# %% [markdown]
# ### Exponential moving average
#
# Sometimes (very often, in fact), to smooth a time series, it is desirable to weight recent realizations of the time series more than older ones. A popular way of doing this is to use an **exponential moving average** (EMA), which for any given time $t$ (assuming $t > 1$), can be calculated by applying the following recursive function:
#
# $$\text{EMA}_y(t, \alpha) = \alpha \cdot y_t + (1 - \alpha) \cdot \text{EMA}_y(t - 1, \alpha)$$
#
# where:
#
#   - $y_t$ and $y_{t-1}$ are the realizations of the time series $y$ at times $t$ and $t-1$ respectively
#   - $\text{EMA}_y(t, \alpha)$ is the value of the EMA of $y$ at time $t$
#   - $\text{EMA}_y(t - 1, \alpha)$ is the value of the EMA of $y$ at time $t - 1$
#   - $\alpha$ is the **exponential smoothing factor**, whose value may range between 0 and 1 ($0 < \alpha < 1$). It represents the degree to which recent realizations are favoured. A greater value of $\alpha$ discounts older realizations faster.
#
# **NOTE**: At time $t = 1$, the function needs to be initialized by either setting it equal to $y_1$, or as a mean calculated across the first few realizations of $y$.
#
# Similar to the SMA, the smoothed signal $y\prime$ is produced from the original time series $y$ by applying the EMA:
#
# $$y_t\prime = \text{EMA}_y(t, \alpha)$$

# %% [markdown]
# **NOTE**: An important consequence of the recursive character of the EMA is that, depending on the values of $\alpha$ and the initialization method, the early outcomes of the EMA should be disregarded. These outcomes are unreliable, since the EMA requires several iterations to converge to reliable values. This is sometimes called **relaxation** of the EMA.

# %% [markdown]
# #### Analogy between EMA and SMA
#
# There is a loose analogy between $k$ of the SMA and $\alpha$ of the EMA, as similar to $k$, bigger values of $\alpha$ will yield a smoother signal. The differences between the original and smoothed signal (sometimes referred to as errors) of $\text{EMA}(t, \alpha)$ and $\text{SMA}(t, k)$ have roughly the same distribution when $\alpha = 2 / (k + 1)$.
#
# Importantly, the EMA takes into account all past data, whereas the SMA only takes into account $k$ past data points. Another key difference between the EMA and the SMA is that calculation of the SMA requires the past $k$ signal realizations, whereas calculation of EMA only requires the most recent realization and the preceding value of the EMA, which makes the EMA less memory demanding and computationally "cheaper."
#
# There are numerous modifications of the SMA and the EMA as well as additional alternatives. For more details about these we recommend visiting: https://en.wikipedia.org/wiki/Moving_average (Moving Average, n.d.).

# %% [markdown]
# **EXERCISE 2**

# %% [markdown]
# 1. Apply simple and exponential moving averages to smooth the `births` time series, using different parameters. <br><br>
#
# 2. Determine if the number of births across weekdays differ from the average.

# %%
# Calculate the moving average
rol_short = births.Births.rolling(window = 7)
rol_long = births.Births.rolling(window = 31)

# Add both to the data frame as a new columns
births['SMA_short'] = rol_short.mean()
births['SMA_long'] = rol_long.mean()

# %%
# Plot simple moving averages along the original signal
plt.plot(births.index, 
         births.Births, 
         color = 'blue', 
         alpha = 0.4)

plt.plot(births.index, 
         births.SMA_short, 
         color = 'red')

plt.plot(births.index, 
         births.SMA_long, 
         color = 'green')

# %%
births['EMA_short'] = births.Births.ewm(alpha=0.25, adjust=True).mean()
births['EMA_long'] = births.Births.ewm(alpha=0.05).mean()

# %%
plt.plot(births.index, 
         births.Births, 
         color = 'blue', 
         alpha = 0.4)

plt.plot(births.index, 
         births.EMA_short, 
         color = 'orange')

plt.plot(births.index, 
         births.EMA_long, 
         color = 'green')

# %%
# Calculate the difference from the short 7 day moving average
births['Diff'] = births.Births - births.SMA_short

# Identify day of the week (0 - Monday, 6 - Sunday)
births['Day'] = births.index.dayofweek

# Plot the results
births.Diff.groupby(births.Day).mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
births.shape
# Out:
# (365, 7)

# %%
births
# Out:
#             Births  SMA_short   SMA_long  EMA_short   EMA_long       Diff  Day
# Date
# 1959-01-01      35        NaN        NaN  35.000000  35.000000        NaN    3
# 1959-01-02      32        NaN        NaN  33.285714  33.461538        NaN    4
# 1959-01-03      30        NaN        NaN  31.864865  32.248028        NaN    5
# 1959-01-04      31        NaN        NaN  31.548571  31.911621        NaN    6
# 1959-01-05      44        NaN        NaN  35.629962  34.583451        NaN    0
# ...            ...        ...        ...        ...        ...        ...  ...
# 1959-12-27      37  40.714286  42.000000  39.324949  42.109766  -3.714286    6
# 1959-12-28      52  40.571429  42.032258  42.493711  42.604278  11.428571    0
# 1959-12-29      48  41.857143  42.096774  43.870284  42.874064   6.142857    1
# 1959-12-30      55  44.000000  42.451613  46.652713  43.480361  11.000000    2
# 1959-12-31      50  45.714286  42.387097  47.489535  43.806343   4.285714    3
#
# [365 rows x 7 columns]

# %% [markdown]
# **Solution**

# %% [markdown]
# We will first calculate the simple moving average. We will use the pandas `rolling` function, using two different windows sizes: 7 days and 30 days.

# %%
# Calculate the moving average
rol_short = births.Births.rolling(window = 7)
rol_long = births.Births.rolling(window = 31)

# Add both to the data frame as a new columns
births['SMA_short'] = rol_short.mean()
births['SMA_long'] = rol_long.mean()

# %%
# Plot simple moving averages along the original signal
plt.plot(births.index, 
         births.Births, 
         color = 'blue', 
         alpha = 0.4)

plt.plot(births.index, 
         births.SMA_short, 
         color = 'red')

plt.plot(births.index, 
         births.SMA_long, 
         color = 'green')

# %% [markdown]
# We will calculate the exponential moving average using the pandas `ewm` function. We will use long and short memory smoothing with parameter $\alpha$ equal 0.25 and 0.05 respectively.

# %%
births['EMA_short'] = births.Births.ewm(alpha=0.25, adjust=True).mean()
births['EMA_long'] = births.Births.ewm(alpha=0.05).mean()

# %%
plt.plot(births.index, 
         births.Births, 
         color = 'blue', 
         alpha = 0.4)

plt.plot(births.index, 
         births.EMA_short, 
         color = 'orange')

plt.plot(births.index, 
         births.EMA_long, 
         color = 'green')

# %% [markdown]
# Let's take a look if the number of births across weekdays differ from the short moving average.

# %%
# Calculate the difference from the short 7 day moving average
births['Diff'] = births.Births - births.SMA_short

# Identify day of the week (0 - Monday, 6 - Sunday)
births['Day'] = births.index.dayofweek

# Plot the results
births.Diff.groupby(births.Day).mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
births.shape
# Out:
# (365, 7)

# %%
births
# Out:
#             Births  SMA_short   SMA_long  EMA_short   EMA_long       Diff  Day
# Date
# 1959-01-01      35        NaN        NaN  35.000000  35.000000        NaN    3
# 1959-01-02      32        NaN        NaN  33.285714  33.461538        NaN    4
# 1959-01-03      30        NaN        NaN  31.864865  32.248028        NaN    5
# 1959-01-04      31        NaN        NaN  31.548571  31.911621        NaN    6
# 1959-01-05      44        NaN        NaN  35.629962  34.583451        NaN    0
# ...            ...        ...        ...        ...        ...        ...  ...
# 1959-12-27      37  40.714286  42.000000  39.324949  42.109766  -3.714286    6
# 1959-12-28      52  40.571429  42.032258  42.493711  42.604278  11.428571    0
# 1959-12-29      48  41.857143  42.096774  43.870284  42.874064   6.142857    1
# 1959-12-30      55  44.000000  42.451613  46.652713  43.480361  11.000000    2
# 1959-12-31      50  45.714286  42.387097  47.489535  43.806343   4.285714    3
#
# [365 rows x 7 columns]

# %% [markdown]
# We can see that the number of births is lower on weekends and Mondays.

# %% [markdown]
# ## Autocorrelation Analysis

# %% [markdown]
# **Autocorrelation**, sometimes referred to as serial correlation, is a correlation between the actual values of the time series and its preceding values, as a function of the delay between them. Mathematically, this is expressed as:
#
# $$R_{yy}(\tau) = \frac{E\big[(y_t - \mu)(y_{t + \tau} - \mu)\big]}{\sigma^2}$$
#
#
# where:
#
#   - $y$ is the time series, sometimes called the **signal**
#   - $R_{yy}$ denotes autocorrelation of the time series $y$
#   - $\tau$ is a delay between the actual values and preceding ones; and is often called **lag**
#   - $y_t$, $y_{t + \tau}$ are realizations of the time series $y$ recorded at times $t$ and $t + \tau$, respectively
#   - $E$ is the **expected value** operator. It is the *de facto* long-term average of the argument: $(y_t - \mu)(y_{t - \tau} - \mu)$
#   - $\mu$ and $\sigma$ are the mean and standard deviation of $y$
#
# By removing the normalization term $\sigma^2$, we obtain **autocovariance**, which is frequently used as an alternative to autocorrelation:
#
# $$C(\tau) = E[(y_t - \mu)(y_{t - \tau} - \mu)]$$
#
#
# **NOTE**: In some literature, the term autocorrelation and autocovariance are used interchangeably. However, there are at least two substantial differences between them:
#
# - Autocovariance is resistant to cases when $\sigma = 0$, which makes it useful in cases when we don't know $\sigma$ prior to the calculation of autocorrelation (i.e. when there is a chance that the time series is constant).
#
#
# - Autocorrelation, in contrast to autocovariance, is normalized &mdash; i.e. it can be used for comparison of time series with very different ranges of values (e.g. a record of two different stocks)
#
# Autocorrelation is a special case of a more general function called **cross-correlation**, $R_{yy}(\tau)$:
#
# $$R_{xy}(\tau) = \frac{E\big[(x_t - \mu_x)(y_{t + \tau} - \mu_y)\big]}{\sigma_x \sigma_y}$$

# %% [markdown]
# ### Properties of autocorrelation
#
# There are several interesting properties of autocorrelation that are worth mentioning:
#
#   - $R_{yy}(\tau)$ is an even function, which means that $R_{yy}(\tau) = R_{yy}(-\tau)$
#   - The autocorrelation of a continuous signal reaches its peak at $\tau = 0$, and for any value of $\tau$: $|R_{yy}(\tau)| < R_{yy}(0)$
#   - The autocorrelation of a periodic signal is always periodic with the same period
#   - The autocorrelation of the sum of two completely uncorrelated signals (i.e. the cross-correlation is equal to zero for all values of $\tau$) equals the sum of the autocorrelations of each signal separately
#   - If the autocorrelation of a signal is equal to zero for all $\tau > 0$, we say the signal is **white noise**

# %% [markdown]
# ### How to estimate autocorrelation
#
# When time is discretized and the values of $\mu$ and $\sigma$ can be calculated beforehand, the autocorrelation can be estimated by the following formula:
#
# $$\hat{R}_{yy}(k) = \frac{1}{(n - k)\sigma^2} \sum_{t = 1}^{n - k}(y_t - \mu)(y_{t + k} - \mu)$$
#
#
# where:
#
# - $k$ is the lag &mdash; i. e. the number of time intervals between the actual and preceding realizations of $y$ (discrete analogy to $\tau$)
# - $n$ is the number of realizations in the given sample &mdash; i.e. the number of data points over which we are going to calculate the autocorrelation
# - $\mu$ and $\sigma$ are the mean and standard deviation of $y$ calculated across the sample

# %% [markdown]
# ### Partial autocorrelation
#
# **Partial autocorrelation** ($\Phi$) measures the autocorrelation of one variable at a given lag, after removing the effect of all shorter lags.
#
# For example, the partial autocorrelation of lag $\tau = 2$ measures correlation between $y_t$ and $y_{t-2}$ after removing the effect of $y_{t-1}$ on both $y_t$ and $y_{t-1}$. Partial autocorrelation can be defined in multiple ways. Probably the simplest formulation is the following recursive scheme:
#
# $$\Phi_{t}(\tau) = \frac{R_{t}(\tau) - \sum^{\tau - 1}_{j = 1}\,\Phi_{t-1}(j)\cdot R_{t}(\tau - 1)}{1 - \sum^{\tau - 1}_{j = 1}\,\Phi_{t-1}(j)\cdot R_{t}(\tau - 1)}$$
#
#
# where:
#
#   - $R_t(\tau)$ is the autocorrelation, as measured at time $t$ with lag $\tau$
#   - $\Phi_t(\tau)$ is the partial autocorrelation, as measured at time $t$ with lag $\tau$

# %% [markdown]
# ### Correlogram
#
# Plotting the dependence of $R_{yy}(\tau)$ on $\tau$, we obtain a **correlogram**, or **lag plot**. A correlogram is an extremely useful tool for visual examination of the properties of a time series. Correlograms can be used to assess various important properties of time series, including:
#
#   - Is the observed signal **random**?
#
#
#   - Is the observed signal **periodical**?
#
#
#   - Is the observed signal **autoregressive**? (can it be modelled by autoregression, covered in a later section)

# %% [markdown]
# **EXERCISE 3**

# %% [markdown]
# 1.) Use the `passengers` and `births` time series to calculate and plot:
#
# - Autocorrelation
#
#
# - Partial autocorrelation
#
#
# 2.) Answer the following questions:
#
# - International flights experienced an extremely high number of passengers relative to expectations for a given month. What does this imply for the number of passengers in the next consecutive 12 months?
#
#
# - Is there an association between the number of births in a given day and the week prior? If yes, what would be the explanation? (Consider the results of the previous exercises)

# %%
# Set the number of lags
max_lag = 50

# %%
# Calculate passengers autocorrelation 
# using the lags ranging from 1 to 50 months
passengers_ac = [passengers.n_passengers.autocorr(lag=i) for i in range(max_lag)]

# Calculate births autocorrelation 
# using the lags ranging from 1 to 50 days
births_ac = [births.Births.autocorr(lag=i) for i in range(max_lag)]

# %%
# Plot the results
plt.plot(range(max_lag), passengers_ac, 'o-')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
# Out:
# Text(0, 0.5, 'Autocorrelation')

# %%
# Plot the results
plt.plot(range(max_lag), births_ac, 'o-')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
# Out:
# Text(0, 0.5, 'Autocorrelation')

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
pd.plotting.autocorrelation_plot(passengers.n_passengers, ax = ax1)
pd.plotting.autocorrelation_plot(births.Births, ax = ax2)

ax1.set_title('Passengers')
ax2.set_title('Births')

ax1.set_xlim(0, max_lag)
ax2.set_xlim(0, max_lag)

fig.subplots_adjust(hspace = 0.8)
plt.show()

# %%
tsaplots.plot_pacf(passengers.n_passengers, lags=30)
tsaplots.plot_pacf(births.Births, lags=30)
plt.show()

# %% [markdown]
# **Solution**

# %% [markdown]
# We will start with calculating the autocorrelation of both series.

# %%
# Set the number of lags
max_lag = 50

# %%
# Calculate passengers autocorrelation 
# using the lags ranging from 1 to 50 months
passengers_ac = [passengers.n_passengers.autocorr(lag=i) for i in range(max_lag)]

# Calculate births autocorrelation 
# using the lags ranging from 1 to 50 days
births_ac = [births.Births.autocorr(lag=i) for i in range(max_lag)]

# %%
# Plot the results
plt.plot(range(max_lag), passengers_ac, 'o-')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
# Out:
# Text(0, 0.5, 'Autocorrelation')

# %% [markdown]
# The signal in the `passengers` time series is strongly correlated with its previous values from 12, 24, 36 and 48 months ago. This indicates the annual periodicity of the signal.

# %%
# Plot the results
plt.plot(range(max_lag), births_ac, 'o-')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
# Out:
# Text(0, 0.5, 'Autocorrelation')

# %% [markdown]
# The `births` time series shows mild correlation with the value preceding the most recent one by 21 days.

# %% [markdown]
# Using the built-in `pandas` function is a more straightforward way to plot autocorrelation.

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
pd.plotting.autocorrelation_plot(passengers.n_passengers, ax = ax1)
pd.plotting.autocorrelation_plot(births.Births, ax = ax2)

ax1.set_title('Passengers')
ax2.set_title('Births')

ax1.set_xlim(0, max_lag)
ax2.set_xlim(0, max_lag)

fig.subplots_adjust(hspace = 0.8)
plt.show()

# %% [markdown]
# **NOTE**: The grey horizontal lines displayed in the plot correspond to 95% and 99% confidence bands. The solid line is 95% and the dashed line is 99%. In the `passengers` time series, we observe significant autocorrelation up to the lag corresponding to 38 months. In the `births` dataset, the statistically significant values are only associated with lags equal to 7, 21 and 28 days, indicating weekly periodicity of the signal.

# %% [markdown]
# We will calculate the partial correlations. This can be done using the functions provided by in the `tsaplots` package of the `statsmodels` library.

# %%
tsaplots.plot_pacf(passengers.n_passengers, lags=30)
tsaplots.plot_pacf(births.Births, lags=30)
plt.show()

# %% [markdown]
# The blue shaded area indicates the confidence intervals, suggesting that correlation values outside of this area are very likely a correlation and not a statistical fluke. By default, this is set to a 95% confidence interval.

# %% [markdown]
# As we can see, partial autocorrelation tells a slightly different story as compared to the previously used autocorrelation. We can answer the above questions:
#
# - The `passengers` signal values are positively correlated with the preceding previous ones (lag equal to 1), and negatively correlated with the values 2 and 13 months prior. Therefore an extremely high number of passengers in the given month may imply a decline in the following month and possibly (with smaller effect) 13 months from now.
#
#
# - The `births` signal value shows significant correlation with the values 7, 14 and 21 days prior. This may be explained by clinicians scheduling births requiring special care (e.g. c-sections, induced births, etc.) on certain days of the week and across the month (see previous results).

# %% [markdown]
# ## Time Series Decomposition

# %% [markdown]
# Time series decomposition is a technique that deconstructs the observed time series into several time series components, each of which has certain characteristic properties. Time series are usually decomposed into three components:
#
# 1. **Trend** ($T(t)$) reflects the long-term progression of the time series. A trend component is present if there is a persistent increase or decrease of the signal.<br><br>
#
# 2. **Seasonality** or the seasonal component ($S(t)$) reflects the repeating changes of the time series. A seasonal component is present if the signal changes in repeating cycles with a fixed period. This occurs when the time series is affected by some periodic factors (e.g. seasonality throughout the year, day and night periodicity, etc.).<br><br>
#
# 3. **Noise** or the irregular component ($I(t)$) reflects the irregularities of the time series. Noise represents the residuals of the observed time series after the other two components have been extracted.
# <br>
# <blockquote><b>NOTE:</b> In some cases decomposition of the time series involves a fourth component, often referred to as <b>cyclicality</b> or the <b>cyclic</b> component ($C(t)$), that reflects the repeating changes of the times series that, in contrast to those reflected by seasonality, don't have a fixed period. Here we will limit ourselves to cases where the time series is decomposed into just the three above mentioned components, ignoring the cyclic component.</blockquote>

# %% [markdown]
# A time series is considered to be a combination of these three components. This combination can be either **additive** or **multiplicative**. Additive decomposition (also known as an **additive model**) assumes the observed time series is a sum of the individual components:
#
# $$y_t = T(t) + S(t) + I(t)$$
#
#
# Multiplicative decomposition (also known as a **multiplicative model**) assumes the observed time series is a product of the individual components:
#
# $$y_t = T(t) \cdot S(t) \cdot I(t)$$
#
#
# The additive decomposition is conducted as follows:
#
# 1. If frequency of the time series, $F$, is an even number, calculate the estimate of the trend component $\hat{T}(t)$, by calculating the $2 \cdot F$ moving average. If $F$ is an odd number, estimate the trend by calculating the $F$ moving average.<br><br>
#
# 2. Calculate the **detrended** time series by subtracting the trend estimate: $y_t - \hat{T}(t)$.<br><br>
#
# 3. Average the detrended values across the presumed period &mdash; i.e. calculate the average across the sets of $F$ consecutive values of $y_t - \hat{T}(t)$ to obtain the estimate of seasonality $\hat{S}(t)$.<br><br>
#
# 4. Calculate the noise component by subtracting the trend and seasonality estimates: $\hat{I}(t) = y_t - \hat{T}(t) - \hat{S}(t)$.
#
# **NOTE**: Multiplicative decomposition is conducted by an analogous procedure, but division is applied instead of subtraction.

# %% [markdown]
# ### When to use additive and multiplicative decomposition
#
# In general, the additive model is more appropriate if the magnitude of the seasonal component does not vary much with the actual signal. When there is an association between the two, the multiplicative model is more appropriate. Additive decomposition is more common when working with agricultural, epidemiological, or other biological time series. Multiplicative decompositions are more common with financial and economic time series.

# %% [markdown]
# ### Seasonality adjusted time series
#
# Sometimes, the variation of the time series due to seasonality is not of interest. For example:
#
#   - Monthly unemployment rates are usually affected by seasonal variation (e.g. an increase in unemployment due to people leaving school and seeking work), thus complicating the ability to assess the underlying state of the labour market
#
#
#   - Flu rates are heavily affected by seasonality (e.g. high incidence rate during cold months), which complicates assessment of the underlying epidemiologic situation
#
# Therefore, time series are often adjusted by removing the seasonal component from the original time series, producing the **seasonally adjusted signal**. For an additive decomposition, the seasonally adjusted signal is given by $y_t - S(t)$, and for a multiplicative model, the seasonally adjusted signal is given by $y_t / S(t)$.

# %% [markdown]
# ### Measuring the strength of trend and seasonality
#
# Sometimes we want to know how "strong" the effect of trend and/or seasonality is in our time series. The strength of a trend can be quantified by assessing its contribution to the overall variance of the signal. For a strongly trended signal, the seasonally adjusted data should have more variation than the remainder component. For an additive model, this can be mathematically formulated as follows:
#
# $$A_T = \text{max}\Big(0, 1 - \frac{\text{Var}\big(I(t)\big)}{\text{Var}\big(T(t) + I(t)\big)}\Big)$$
#
#
# Analogously, strength of seasonality can be formulated as:
#
# $$A_S = \text{max}\Big(0, 1 - \frac{\text{Var}\big(I(t)\big)}{\text{Var}\big(S(t) + I(t)\big)}\Big)$$
#
#
# where:
#
#   - $A_T$ and $A_S$  are the strength of trend and seasonality, respectively
#   - $T(t)$ is trend
#   - $S(t)$ is seasonality
#   - $I(t)$ is noise (irregularity component)
#
# For multiplicative models, the denominators in the above equations contain multiplication instead of addition.

# %% [markdown]
# **EXERCISE 4**

# %% [markdown]
# Using the `passengers` and `births` datasets:
#
#   - Decompose the signal into trend, seasonality and noise, and plot the results
#   - Decide which of the two models (additive or multiplicative) provides a better decomposition of the signal
#   - Remove the trend from the time series to see how the signal changes. Repeat by removing seasonality.
#   - Assess how strong the contribution of trend and seasonality are to the signal

# %%
# Additive model
passengers_add = seasonal_decompose(passengers.n_passengers, 
                                    model='additive')

# Multiplicative model
passengers_mlt = seasonal_decompose(passengers.n_passengers, 
                                    model='multiplicative')

# %%
p1 = passengers_add.plot()
p2 = passengers_mlt.plot()
plt.show()

# %%
# Take the residuals of both models and remove NaNs
r1 = passengers_add.resid.dropna()
r2 = passengers_mlt.resid.dropna()

# Calculate means
mu1 = r1.mean()
mu2 = r2.mean()

# Plot histograms
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.hist(r1)
ax2.hist(r2)

# Add titles
ax1.set_title('Additive')
ax2.set_title('Multiplicative')

# Add vertical lines to highlight the means
ax1.axvline(x = mu1, 
            color='r', 
            linestyle='dashed', 
            linewidth=2)

ax2.axvline(x = mu2, 
            color='r', 
            linestyle='dashed', 
            linewidth=2)

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)

pd.plotting.autocorrelation_plot(r1, ax = ax1)
pd.plotting.autocorrelation_plot(r2, ax = ax2)

# Add titles
ax1.set_title('Additive')
ax2.set_title('Multiplicative')

plt.subplots_adjust(hspace = 0.9)
plt.show()

# %%
passengers['detrended'] = passengers.n_passengers / passengers_mlt.trend
passengers['deseasoned'] = passengers.n_passengers / passengers_mlt.seasonal

fix, (ax1, ax2) = plt.subplots(2, 1)
passengers['detrended'].plot(ax = ax1)
passengers['deseasoned'].plot(ax = ax2)

ax1.set_ylabel('N')
ax2.set_ylabel('N')

ax1.set_title('Detrended')
ax2.set_title('Deseasoned')

plt.subplots_adjust(hspace = 0.9)
plt.show()

# %%
trend_strength = 1. - np.var(passengers_mlt.resid) / np.var(passengers_mlt.resid * passengers_mlt.trend)
seasonality_strength = 1. - np.var(passengers_mlt.resid) / np.var(passengers_mlt.resid + passengers_mlt.seasonal)

# %%
print ('Strength of trend is: %1.3f' % trend_strength)
print ('Strength of seasonality is: %1.3f' % seasonality_strength)
# Out:
# Strength of trend is: 1.000
# Strength of seasonality is: 0.936

# %% [markdown]
# **Solution**

# %% [markdown]
# We will first decompose the signal of the `passengers` time series. To do this we will use the `statsmodels` function `seasonal_decompose`.

# %%
# Additive model
passengers_add = seasonal_decompose(passengers.n_passengers, 
                                    model='additive')

# Multiplicative model
passengers_mlt = seasonal_decompose(passengers.n_passengers, 
                                    model='multiplicative')

# %% [markdown]
# Now, we will plot the decomposed signal.

# %%
p1 = passengers_add.plot()
p2 = passengers_mlt.plot()
plt.show()

# %% [markdown]
# At first look, additive and multiplicative models produce similar results.
#
# One way to decide which model is better in this case, is to examine the properties of the white noise component (here called residuals). Ideally, the noise should be white noise (i.e. an independent, normally distributed signal with zero mean).

# %%
# Take the residuals of both models and remove NaNs
r1 = passengers_add.resid.dropna()
r2 = passengers_mlt.resid.dropna()

# Calculate means
mu1 = r1.mean()
mu2 = r2.mean()

# Plot histograms
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.hist(r1)
ax2.hist(r2)

# Add titles
ax1.set_title('Additive')
ax2.set_title('Multiplicative')

# Add vertical lines to highlight the means
ax1.axvline(x = mu1, 
            color='r', 
            linestyle='dashed', 
            linewidth=2)

ax2.axvline(x = mu2, 
            color='r', 
            linestyle='dashed', 
            linewidth=2)

plt.show()

# %% [markdown]
# The residuals of the additive model have a much "broader" distribution. Now we can assess the independence of the residuals by calculating their autocorrelation.

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)

pd.plotting.autocorrelation_plot(r1, ax = ax1)
pd.plotting.autocorrelation_plot(r2, ax = ax2)

# Add titles
ax1.set_title('Additive')
ax2.set_title('Multiplicative')

plt.subplots_adjust(hspace = 0.9)
plt.show()

# %% [markdown]
# In both cases we observe that the noise shows some correlation with its previous values. However, in the case of the additive model, the autocorrelation is much stronger. We can conclude that the multiplicative model is the better alternative.

# %% [markdown]
# Next, we will remove the trend from the signal. Using the multiplicative model, we divide the signal by the trend component.

# %%
passengers['detrended'] = passengers.n_passengers / passengers_mlt.trend
passengers['deseasoned'] = passengers.n_passengers / passengers_mlt.seasonal

fix, (ax1, ax2) = plt.subplots(2, 1)
passengers['detrended'].plot(ax = ax1)
passengers['deseasoned'].plot(ax = ax2)

ax1.set_ylabel('N')
ax2.set_ylabel('N')

ax1.set_title('Detrended')
ax2.set_title('Deseasoned')

plt.subplots_adjust(hspace = 0.9)
plt.show()

# %%
trend_strength = 1. - np.var(passengers_mlt.resid) / np.var(passengers_mlt.resid * passengers_mlt.trend)
seasonality_strength = 1. - np.var(passengers_mlt.resid) / np.var(passengers_mlt.resid + passengers_mlt.seasonal)

# %%
print ('Strength of trend is: %1.3f' % trend_strength)
print ('Strength of seasonality is: %1.3f' % seasonality_strength)
# Out:
# Strength of trend is: 1.000
# Strength of seasonality is: 0.936

# %% [markdown]
# The strength of the trend is greater than the strength of seasonality.
#
# Analogous analysis can be conducted for the `births` time series. Please try this on your own.

# %% [markdown]
# ## Modelling of Time Series and Forecasting

# %% [markdown]
# Naturally, people are often interested in how a time series will continue to evolve in the future. There are numerous methods that have been developed to model the behaviour of times series to predict their future. Most of these methods utilize either regression analysis, some type of moving average, or a combination of both. In the following section, we will discuss the most fundamental of these methods.

# %% [markdown]
# ### Autoregression models
#
# Time series regression is the application of regression analysis on time series data. The most common type of time series regression is linear regression, where the response is the actual value of the time series, and predictors (features) are its preceding values. This type regression is called **autoregression**, as it uses the historical values of the time series to estimate the values of the same time series.
#
# Autoregression can be mathematically expressed as follows:
#
# $$\hat{y}_t = \beta_0 + \beta_1 y_{t-1} + \beta_2 y_{t-2} + \ldots + \beta_p y_{t-p} + e_t$$
#
#
# or, more compactly:
#
#
# $$\hat{y}_t = \beta_0 + \sum^{p}_{i = 1}\beta_i y_{t-i} + e_t$$
#
# where:
#
#   - $\hat{y}$ is the **forecasted value** (or simply the forecast) of the signal $y$ for time $t$
#   - $\beta_0$ is the **autoregression constant**. It is the equivalent of the intercept term in previously described regression analysis.
#   - $\beta_i$ for $i = 1, 2,\ldots, p$ are the **autoregression coefficients**
#   - $p$ is the **order of the autoregression**, indicating the **maximum lag** of the autoregression
#   - $e_t$ is called **white noise**. It is the **error term** equivalent to those of regression analysis. White noise can be thought of as the time series whose values are normally distributed with mean equal to zero.
#
# Estimates of the autoregression coefficients constitute an **autoregression model (AR)** of the $p$-th order, often denoted as $\text{AR}(p)$. The fact that the autoregression model is used to predict the future values is then expressed as: $\hat{y}_t = \text{AR}(p)$.

# %% [markdown]
# #### The choice of the maximum lag
#
# An important aspect of autoregression is **the choice of the maximum lag** $p$ (order of the autoregression) &mdash; i.e. how far into the past the autoregression goes to predict the future. The maximum lag can be estimated using the **partial autocorrelation** of the times series.
#
# Typically, as the lag increases, the absolute value of the partial autocorrelation quickly decreases, approaching zero. The lag beyond which all the partial autocorrelations are equal (or very close) to zero can be used as the maximum lag of the autoregression/moving average. However, generally it is safer to use lag that is incremented by one time step from this. Mathematically:
#
# $$p = k + 1,\,|\Phi(i)| = 0\,\,; \forall i > k$$

# %% [markdown]
# ### Moving average model
#
# The **moving average (MA) model** is another common approach for time series forecasting which, rather than using the past values of the time series, the past forecast errors are used in a regression-like model:
#
# $$\hat{y}_t = \mu_y + \epsilon_{t} + \theta_1 \epsilon_{t-1} + \ldots + \theta_q \epsilon_{t-q}$$
#
#
# or, more compactly:
#
# $$\hat{y}_t = \mu_y + e_t + \sum^{q}_{i = 1} \theta_i \epsilon_{t-i}$$
#
#
# where:
#
# - $\hat{y}$ is the **forecasted value** of the signal $y$ for time $t$
# - $\mu_y$ is the mean of the time series $y$
# - $\theta_i$ for $i = 1, 2,\ldots, q$ are the **model parameters**
# - $q$ is the **order of the moving average**
# - $\epsilon_{t-i}$  for $i = 1, 2,\ldots, q$ are the white noise **error terms** obtained from the previous forecasts, sometimes called **random shocks**. They are typically assumed to come from the normal distribution with zero mean.
# - $e_t$ is the error term (white noise) of the actual prediction, the equivalent of $e_t$ in autoregression
# <br>
# <blockquote>
# <b>NOTE:</b> Error terms of the moving average model are different from those of the autoregression model. Unlike error terms of autoregression, they are affected by the preceding predictions. Hence different notation.
# </blockquote>
#
# The fact that the moving average model of the $q$-th order is used to predict the future values is expressed as: $\hat{y}_t = \text{MA}(q)$

# %% [markdown]
# #### A few important notes about the moving average model
#
# - The MA model assumes the time series is **stationary** &mdash; i.e. its mean and standard deviation don't change very much over time. This is a very strong assumption that typically holds only temporarily. Therefore, MA models have only a limited "life span" and after some time, need to be re-estimated.
#
#
# - Conceptually, the moving average model is a linear regression, but, because we do not observe the $\epsilon$ values directly, it is not really a linear regression in the usual sense.
#
#
# - Error terms from the previous time step **propagate** to future predictions, as they become predictors in the next time step. Hence, each error term affects only the next $q$ consecutive estimates of $y$. This gives MA models substantial advantage over AR models, as even major irregularities (spikes, dropdowns) in the time series affect the predictions only in the next few steps.
#
#
# - The name "moving average model" comes from the fact that each value of $\hat{y}$ can be thought of as a weighted moving average of the past $q$ forecast errors. Importantly, a moving average model must not be confused with moving average smoothing:<br><br>
#
#   - A **moving average model** is used for forecasting future values of a time series<br><br>
#
#   - **Moving average smoothing** is used for noise filtering and for trend estimation<br><br>
#
# - Fitting an MA model is more complicated than AR model fitting. This is because the lagged error terms $\epsilon$ are not directly observable. Therefore, **iterative methods for non-linear fitting** are applied instead of traditional linear least squares. A description of these methods is not the subject of this material, but can be found here: https://www.it.uu.se/research/publications/reports/2006-022/2006-022-nc.pdf (Sandgren & Stoica, 2006).

# %% [markdown]
# #### The choice of the maximum lag
#
# **Order of the moving average model** (maximum lag) can be estimated from the autocorrelation function (not necessarily partial autocorrelation). Similar to the order of the autoregression model, the maximum lag should be equal to the lag beyond which autocorrelation is equal to zero, typically increased by one.

# %% [markdown]
# ### Autoregressive moving average (ARMA) model (and its extensions)

# %% [markdown]
# The **ARMA model** (sometimes called the Box-Jenkins model), is combination of the autoregression and moving average models:
#
# $$\hat{y}_t = \beta_0 + \sum^{p}_{i = 1}\beta_i y_{t-i} + \sum^{q}_{i = 1} \theta_i \epsilon_{t-i} + e_t$$
#
#
# where the notation remains the same as in the case of autoregression and autocorrelation. The application of the ARMA model to predict $y_t$ is expressed as:
#
# $$\hat{y}_t = \text{ARMA}(p, q)$$
#
#
# **Importantly**, the ARMA model, similar to MA models, assumes that the time series is stationary &mdash; i.e. its mean and standard deviation don't change very much over time. This assumption typically holds only for a short period of time, after which the mean "drifts away." To overcome this limitation, a generalization of the ARMA model, called **ARIMA** has been proposed.
#
# The **ARIMA model** (Autoregressive integrated moving average model) is a generalization of the ARMA model, that accounts for the non-stationarity of the time series. The ARIMA model is formally identical to ARMA, but requires an initial **differencing step** to be applied (one or multiple times) to the time series $y$ in order to eliminate non-stationarity. **"Differencing of the time series"** means the difference between consecutive observations is computed. Mathematically, this is expressed as:
#
# $$y\prime_t = y_t - y_{t-1}$$
#
#
# Sometimes second order differencing is applied:
#
# $$y\prime\prime_t = y\prime_t - y\prime_{t-1}$$
#
#
# Application of the ARIMA model to predict $y_t$ is expressed as:
#
# $$\hat{y}_t = \text{ARIMA}(p, d, q)$$
#
#
# where $d$ indicates the order of the differencing used prior to the application of the ARMA model. Therefore ARMA, AR, MA can be thought of as special cases of ARIMA, particularly:
#
#   - $\text{ARIMA}(p, 0, q)$ model is $\text{ARMA}(p, q)$
#   - $\text{ARIMA}(p, 0, 0)$ model is $\text{AR}(p)$
#   - $\text{ARIMA}(0, 0, q)$ model is $\text{MA}(q)$
#   - $\text{ARIMA}(0, 0, 0)$ model is **white noise**
#   - $\text{ARIMA}(0, 1, 0)$ model ($y_t = y_{t-1} + \epsilon_t$) is a random signal, called a **random walk**
#
# There are multiple extensions to the ARMA/ARIMA models, such as SARIMA, ARIMAX, etc., which are not in the scope of this material. More information about these can be found here: https://arxiv.org/pdf/1302.6613.pdf (Adhikari & Agrawal, 2013).

# %% [markdown]
# **EXERCISE 5**

# %% [markdown]
# Use ARIMA to forecast the number of passengers in the forthcoming month.
#
#   - Use 70% of the data for "training" the ARIMA model
#   - Predict the number of passengers in a single forthcoming month ahead
#   - Assess the quality of the predictions across the remaining data

# %% [markdown]
# **Solution**
#
# First, we must assess if the assumption of stationarity of the signal is satisfied. From the previous exercises, we know that signal is not stationary, as there is a strong trend in the signal. To make it stationary we can difference the signal and assess the stationarity of the differenced signal by plotting its moving average and moving standard deviation.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize = (6, 8))

# Plot the passengers numbers
passengers.n_passengers.plot(ax = ax1)

# Plot differentiated signal
passengers.n_passengers.diff().plot(ax = ax2)

# Plot the moving average and moving standard deviation
passengers.n_passengers.diff().rolling(12).mean().plot(ax = ax3, title = 'Stationarity check')
passengers.n_passengers.diff().rolling(12).std().plot(ax = ax3, color = 'green')

# Plot
plt.subplots_adjust(hspace = 0.5)
plt.show()

# %% [markdown]
# As we can see, even the differenced signal is not fully stationary as its standard deviation is growing with time. One simple way to resolve this is to logarithmize the signal prior to differencing:

# %%
passengers['n_passengers_log'] = np.log(passengers['n_passengers'])

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize = (6, 8))
# Plot the log-transformed signal
passengers.n_passengers_log.plot(ax = ax1, title = 'Log-transformed')

# Plot differentiated log-transformed signal
passengers.n_passengers_log.diff().plot(ax = ax2, title = 'Log-transformed diff.')

# Plot the moving average and moving standard deviation
passengers.n_passengers_log.diff().rolling(12).mean().plot(ax = ax3, title = 'Stationarity check')
passengers.n_passengers_log.diff().rolling(12).std().plot(ax = ax3, color = 'green')
plt.subplots_adjust(hspace = 0.5)
plt.show()

# %% [markdown]
# We can now see that the log-transformed, differenced signal is stationary.

# %% [markdown]
# We will split the data into "training" and "validation" sets, using approximately 70% of the data for training.

# %%
n = np.int(len(passengers) * 0.7)
train, test = passengers.iloc[:n], passengers.iloc[n:]
# Out:
# /var/folders/dl/nzqz9d4s48z5l005svj0w2sr0000gn/T/ipykernel_6494/3867652467.py:1: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   n = np.int(len(passengers) * 0.7)

# %% [markdown]
# Now, we will assess the autocorrelation and partial autocorrelation so that we can set the order of the ARIMA model. Autocorrelations outside of the 95% confidence interval will be considered as close to zero.

# %%
p1 = tsaplots.plot_acf(train.n_passengers_log.diff().dropna(), lags=30, alpha=0.05)
p2 = tsaplots.plot_pacf(train.n_passengers_log.diff().dropna(), lags=30, alpha=0.05)
plt.show()
# Out:
# /Users/paulo/opt/anaconda3/lib/python3.9/site-packages/statsmodels/regression/linear_model.py:1434: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# As we can see, autocorrelation and partial correlation at lag = 1 are close to zero. Therefore we may set the order of AR to 1, and the order of MA to 1. We will set the order of differencing to 1, so that we work with the stationary signal (as shown above). We will use log-transformed data.

# %%
arima = ARIMA(train.n_passengers_log.dropna().astype(float), order=(1,1,1))
arima_fit = arima.fit(disp=1, maxiter=100)
print(arima_fit.summary())
# Out:
# /Users/paulo/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# /Users/paulo/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/paulo/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.28378D-01    |proj g|=  1.08958D+01
#
# At iterate    1    f= -9.32826D-01    |proj g|=  9.51332D-01
#
# At iterate    2    f= -9.32860D-01    |proj g|=  1.39805D-02
#
# At iterate    3    f= -9.32860D-01    |proj g|=  1.39808D-02
#
# At iterate    4    f= -9.32860D-01    |proj g|=  2.54973D-02
#
# At iterate    5    f= -9.32860D-01    |proj g|=  5.87818D-02
#
# At iterate    6    f= -9.32861D-01    |proj g|=  1.17680D-01
#
# At iterate    7    f= -9.32862D-01    |proj g|=  2.09544D-01
#
# At iterate    8    f= -9.32866D-01    |proj g|=  3.58872D-01
#
# At iterate    9    f= -9.32875D-01    |proj g|=  5.93970D-01
#
# At iterate   10    f= -9.32898D-01    |proj g|=  9.52839D-01
#
# At iterate   11    f= -9.32954D-01    |proj g|=  1.44619D+00
#
# At iterate   12    f= -9.33074D-01    |proj g|=  1.95023D+00
#
# At iterate   13    f= -9.33261D-01    |proj g|=  2.05570D+00
#
# At iterate   14    f= -9.33430D-01    |proj g|=  1.42957D+00
#
# At iterate   15    f= -9.33506D-01    |proj g|=  5.41565D-01
#
# At iterate   16    f= -9.33520D-01    |proj g|=  6.47788D-02
#
# At iterate   17    f= -9.33521D-01    |proj g|=  5.03300D-03
#
# At iterate   18    f= -9.33521D-01    |proj g|=  1.71745D-03
#
# At iterate   19    f= -9.33521D-01    |proj g|=  6.06959D-05
#
# At iterate   20    f= -9.33521D-01    |proj g|=  8.88178D-07
#
# At iterate   21    f= -9.33521D-01    |proj g|=  4.47420D-06
#
# At iterate   22    f= -9.33521D-01    |proj g|=  4.50751D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     22     30      1     0     0   4.508D-06  -9.335D-01
#   F = -0.93352055638443066
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:     D.n_passengers_log   No. Observations:                   99
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                  92.419
# Method:                       css-mle   S.D. of innovations              0.094
# Date:                Mon, 28 Nov 2022   AIC                           -176.837
# Time:                        17:25:16   BIC                           -166.457
# Sample:                    02-01-1949   HQIC                          -172.637
#                          - 04-01-1957
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.0110      0.001     11.822      0.000       0.009       0.013
# ar.L1.D.n_passengers_log     0.6729      0.076      8.814      0.000       0.523       0.822
# ma.L1.D.n_passengers_log    -1.0000      0.026    -38.736      0.000      -1.051      -0.949
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.4862           +0.0000j            1.4862            0.0000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------
#  This problem is unconstrained.

# %% [markdown]
# Notice that the summary of the model is similar to the summary of the regression model described in previous modules. For more details, please refer to the documentation for the `statsmodels` library: https://devdocs.io/statsmodels/ (Statsmodel developers and others, 2012).

# %% [markdown]
# We will forecast the number of passengers in the forthcoming month.

# %%
p, err, conf = arima_fit.forecast()
print ('Predicted no. of passengers [log]: %1.2f' %  p)
print ('Standard error of the prediction: %1.2f' % err)
print ('COnfidence interval: (%1.2f, %1.2f)' % (conf[0][0], conf[0][1]))

y_hat = np.exp(p)
y = test.n_passengers[0]
# Out:
# Predicted no. of passengers [log]: 5.87
# Standard error of the prediction: 0.09
# COnfidence interval: (5.69, 6.05)

# %% [markdown]
# Now we will compare the predicted values with actual values.

# %%
print ('Predicted number of pasengers: %1.2f' % y_hat)
print ('Actual number of passengers: %i' % y)
print ('Absolute error: %1.2f' % np.abs(y_hat - y))
print ('Relative error %1.2f%%' % (np.abs(y_hat - y) / y * 100))
# Out:
# Predicted number of pasengers: 354.46
# Actual number of passengers: 355
# Absolute error: 0.54
# Relative error 0.15%

# %% [markdown]
# As we can see, the predicted value is quite close to the actual one. Let's extend our validation to other months. We will do iterative **in-sample** forecasting. The history is initially formed of the first 70% of a time series. Then, we will forecast the first point of the test set, and will add the true value to the history. Next, we will forecast the second point, and so on. This will provide us with an evaluation of the model's predictive quality.

# %%
# Define the history
hist = list(train.n_passengers_log.dropna().astype(float))

# Initialize container for predictions
pred = []
for i in range(len(test)):
    # Initalize the model
    arima = ARIMA(hist, order=(6,1,0))
    #Fit the model on the available history
    arima_fit = arima.fit(disp=1, maxiter=500)
    # Take the prediction
    pred.append(arima_fit.forecast()[0][0])   
    # Expand the history
    hist.append(test.n_passengers_log[i])
# Out:
# /Users/paulo/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.49216D-01    |proj g|=  3.86479D-01
#
# At iterate    1    f= -9.49509D-01    |proj g|=  1.76951D-02
#
# At iterate    2    f= -9.49511D-01    |proj g|=  1.02596D-02
#
# At iterate    3    f= -9.49513D-01    |proj g|=  1.54196D-02
#
# At iterate    4    f= -9.49521D-01    |proj g|=  4.77744D-02
#
# At iterate    5    f= -9.49540D-01    |proj g|=  9.15395D-02
#
# At iterate    6    f= -9.49585D-01    |proj g|=  1.52743D-01
#  This problem is unconstrained.
# At iterate    7    f= -9.49672D-01    |proj g|=  2.06669D-01
#
# At iterate    8    f= -9.49789D-01    |proj g|=  1.97128D-01
#
# At iterate    9    f= -9.49889D-01    |proj g|=  8.52466D-02
#
# At iterate   10    f= -9.49913D-01    |proj g|=  4.89089D-03
#
# At iterate   11    f= -9.49915D-01    |proj g|=  2.18523D-02
#
# At iterate   12    f= -9.49917D-01    |proj g|=  3.21269D-02
#
# At iterate   13    f= -9.49922D-01    |proj g|=  4.34077D-02
#
# At iterate   14    f= -9.49931D-01    |proj g|=  4.85255D-02
#
# At iterate   15    f= -9.49942D-01    |proj g|=  3.49915D-02
#
# At iterate   16    f= -9.49946D-01    |proj g|=  1.08611D-02
#
# At iterate   17    f= -9.49947D-01    |proj g|=  7.58171D-04
#
# At iterate   18    f= -9.49947D-01    |proj g|=  8.16103D-04
#
# At iterate   19    f= -9.49947D-01    |proj g|=  1.10328D-03
#
# At iterate   20    f= -9.49947D-01    |proj g|=  1.71675D-03
#
# At iterate   21    f= -9.49947D-01    |proj g|=  5.51413D-03
#
# At iterate   22    f= -9.49947D-01    |proj g|=  4.26300D-03
#
# At iterate   23    f= -9.49948D-01    |proj g|=  2.03058D-03
#
# At iterate   24    f= -9.49948D-01    |proj g|=  3.81484D-04
#
# At iterate   25    f= -9.49948D-01    |proj g|=  3.43270D-04
#
# At iterate   26    f= -9.49948D-01    |proj g|=  9.07141D-04
#
# At iterate   27    f= -9.49948D-01    |proj g|=  2.37557D-03
#
# At iterate   28    f= -9.49948D-01    |proj g|=  2.40051D-03
#
# At iterate   29    f= -9.49948D-01    |proj g|=  5.43487D-04
#
# At iterate   30    f= -9.49948D-01    |proj g|=  2.54330D-04
#
# At iterate   31    f= -9.49948D-01    |proj g|=  3.47056D-05
#
# At iterate   32    f= -9.49948D-01    |proj g|=  7.97473D-05
#
# At iterate   33    f= -9.49948D-01    |proj g|=  1.67455D-04
#
# At iterate   34    f= -9.49948D-01    |proj g|=  1.09779D-04
#
# At iterate   35    f= -9.49948D-01    |proj g|=  2.62890D-04
#
# At iterate   36    f= -9.49948D-01    |proj g|=  1.07203D-04
#
# At iterate   37    f= -9.49948D-01    |proj g|=  9.01501D-06
#
# At iterate   38    f= -9.49948D-01    |proj g|=  1.39888D-06
#
# At iterate   39    f= -9.49948D-01    |proj g|=  6.32827D-07
#
# At iterate   40    f= -9.49948D-01    |proj g|=  2.22045D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     40     47      1     0     0   2.220D-07  -9.499D-01
#   F = -0.94994801354336278
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.52541D-01    |proj g|=  3.81232D-01
#
# At iterate    1    f= -9.52825D-01    |proj g|=  1.71247D-02
#
# At iterate    2    f= -9.52827D-01    |proj g|=  1.05009D-02
#
# At iterate    3    f= -9.52830D-01    |proj g|=  1.60583D-02
#
# At iterate    4    f= -9.52838D-01    |proj g|=  4.84555D-02
#  This problem is unconstrained.
# At iterate    5    f= -9.52857D-01    |proj g|=  9.27506D-02
#
# At iterate    6    f= -9.52903D-01    |proj g|=  1.54027D-01
#
# At iterate    7    f= -9.52990D-01    |proj g|=  2.07080D-01
#
# At iterate    8    f= -9.53106D-01    |proj g|=  1.94975D-01
#
# At iterate    9    f= -9.53198D-01    |proj g|=  8.82993D-02
#
# At iterate   10    f= -9.53221D-01    |proj g|=  3.52577D-03
#
# At iterate   11    f= -9.53223D-01    |proj g|=  1.82839D-02
#
# At iterate   12    f= -9.53224D-01    |proj g|=  2.63750D-02
#
# At iterate   13    f= -9.53228D-01    |proj g|=  3.77628D-02
#
# At iterate   14    f= -9.53237D-01    |proj g|=  4.78892D-02
#
# At iterate   15    f= -9.53250D-01    |proj g|=  4.63253D-02
#
# At iterate   16    f= -9.53258D-01    |proj g|=  4.02146D-02
#
# At iterate   17    f= -9.53263D-01    |proj g|=  7.24409D-04
#
# At iterate   18    f= -9.53263D-01    |proj g|=  2.97884D-04
#
# At iterate   19    f= -9.53263D-01    |proj g|=  4.67815D-04
#
# At iterate   20    f= -9.53264D-01    |proj g|=  2.97717D-04
#
# At iterate   21    f= -9.53264D-01    |proj g|=  2.16971D-04
#
# At iterate   22    f= -9.53264D-01    |proj g|=  1.41342D-04
#
# At iterate   23    f= -9.53264D-01    |proj g|=  3.80584D-05
#
# At iterate   24    f= -9.53264D-01    |proj g|=  8.61533D-06
#
# At iterate   25    f= -9.53264D-01    |proj g|=  8.55205D-05
#
# At iterate   26    f= -9.53264D-01    |proj g|=  3.08087D-05
#
# At iterate   27    f= -9.53264D-01    |proj g|=  3.44169D-07
#
# At iterate   28    f= -9.53264D-01    |proj g|=  3.21965D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     28     32      1     0     0   3.220D-07  -9.533D-01
#   F = -0.95326354136374680
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.47635D-01    |proj g|=  3.60730D-01
#
# At iterate    1    f= -9.47907D-01    |proj g|=  1.43178D-02
#
# At iterate    2    f= -9.47909D-01    |proj g|=  1.01715D-02
#
# At iterate    3    f= -9.47911D-01    |proj g|=  1.77017D-02
#
# At iterate    4    f= -9.47920D-01    |proj g|=  4.88305D-02
#
# At iterate    5    f= -9.47940D-01    |proj g|=  9.29123D-02
#
# At iterate    6    f= -9.47987D-01    |proj g|=  1.50802D-01
#
# At iterate    7    f= -9.48074D-01    |proj g|=  1.95420D-01
#
# At iterate    8    f= -9.48181D-01    |proj g|=  1.70981D-01
#
# At iterate    9    f= -9.48246D-01    |proj g|=  7.64965D-02
#
# At iterate   10    f= -9.48261D-01    |proj g|=  6.13946D-03
#
# At iterate   11    f= -9.48262D-01    |proj g|=  8.67614D-03
#
# At iterate   12    f= -9.48263D-01    |proj g|=  1.18414D-02
#
# At iterate   13    f= -9.48265D-01    |proj g|=  1.90989D-02
#
# At iterate   14    f= -9.48272D-01    |proj g|=  2.89362D-02
#
# At iterate   15    f= -9.48285D-01    |proj g|=  3.84441D-02
#
# At iterate   16    f= -9.48304D-01    |proj g|=  3.83364D-02
#
# At iterate   17    f= -9.48313D-01    |proj g|=  5.55740D-02
#
# At iterate   18    f= -9.48321D-01    |proj g|=  1.01810D-03
#
# At iterate   19    f= -9.48321D-01    |proj g|=  6.56342D-04
#
# At iterate   20    f= -9.48321D-01    |proj g|=  1.43097D-04
#
# At iterate   21    f= -9.48321D-01    |proj g|=  5.31619D-04
#
# At iterate   22    f= -9.48321D-01    |proj g|=  9.06730D-04
#
# At iterate   23    f= -9.48321D-01    |proj g|=  1.02527D-03
#
# At iterate   24    f= -9.48321D-01    |proj g|=  1.65501D-04
#
# At iterate   25    f= -9.48321D-01    |proj g|=  4.47575D-04
#
# At iterate   26    f= -9.48321D-01    |proj g|=  3.64420D-04
#
# At iterate   27    f= -9.48321D-01    |proj g|=  1.43818D-04
#
# At iterate   28    f= -9.48321D-01    |proj g|=  2.80775D-05
#
# At iterate   29    f= -9.48321D-01    |proj g|=  9.02833D-05
#
# At iterate   30    f= -9.48321D-01    |proj g|=  6.95888D-05
#
# At iterate   31    f= -9.48321D-01    |proj g|=  6.12188D-04
#
# At iterate   32    f= -9.48321D-01    |proj g|=  3.27383D-04
#
# At iterate   33    f= -9.48321D-01    |proj g|=  7.27973D-05
#
# At iterate   34    f= -9.48321D-01    |proj g|=  8.32334D-05
#  This problem is unconstrained.
# At iterate   35    f= -9.48321D-01    |proj g|=  4.66294D-05
#
# At iterate   36    f= -9.48321D-01    |proj g|=  1.32783D-05
#
# At iterate   37    f= -9.48321D-01    |proj g|=  1.99840D-06
#
# At iterate   38    f= -9.48321D-01    |proj g|=  5.77316D-06
#
# At iterate   39    f= -9.48321D-01    |proj g|=  5.87308D-06
#
# At iterate   40    f= -9.48321D-01    |proj g|=  4.50751D-06
#
# At iterate   41    f= -9.48321D-01    |proj g|=  4.77396D-07
#
# At iterate   42    f= -9.48321D-01    |proj g|=  1.11022D-07
#
# At iterate   43    f= -9.48321D-01    |proj g|=  8.88178D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     43     49      1     0     0   8.882D-08  -9.483D-01
#   F = -0.94832147889887619
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.44871D-01    |proj g|=  3.31961D-01
#  This problem is unconstrained.
# At iterate    1    f= -9.45119D-01    |proj g|=  1.10156D-02
#
# At iterate    2    f= -9.45120D-01    |proj g|=  9.50341D-03
#
# At iterate    3    f= -9.45124D-01    |proj g|=  1.97146D-02
#
# At iterate    4    f= -9.45132D-01    |proj g|=  4.93860D-02
#
# At iterate    5    f= -9.45154D-01    |proj g|=  9.30625D-02
#
# At iterate    6    f= -9.45202D-01    |proj g|=  1.46088D-01
#
# At iterate    7    f= -9.45286D-01    |proj g|=  1.78646D-01
#
# At iterate    8    f= -9.45377D-01    |proj g|=  1.39218D-01
#
# At iterate    9    f= -9.45421D-01    |proj g|=  5.24012D-02
#
# At iterate   10    f= -9.45428D-01    |proj g|=  3.75197D-03
#
# At iterate   11    f= -9.45429D-01    |proj g|=  4.62822D-03
#
# At iterate   12    f= -9.45429D-01    |proj g|=  6.33387D-03
#
# At iterate   13    f= -9.45432D-01    |proj g|=  1.27542D-02
#
# At iterate   14    f= -9.45439D-01    |proj g|=  2.07179D-02
#
# At iterate   15    f= -9.45452D-01    |proj g|=  2.76703D-02
#
# At iterate   16    f= -9.45468D-01    |proj g|=  2.59565D-02
#
# At iterate   17    f= -9.45478D-01    |proj g|=  1.00471D-02
#
# At iterate   18    f= -9.45478D-01    |proj g|=  2.92019D-03
#
# At iterate   19    f= -9.45478D-01    |proj g|=  6.89082D-04
#
# At iterate   20    f= -9.45478D-01    |proj g|=  4.18976D-04
#
# At iterate   21    f= -9.45479D-01    |proj g|=  3.38163D-04
#
# At iterate   22    f= -9.45479D-01    |proj g|=  8.14948D-04
#
# At iterate   23    f= -9.45479D-01    |proj g|=  9.33709D-04
#
# At iterate   24    f= -9.45479D-01    |proj g|=  1.20037D-03
#
# At iterate   25    f= -9.45479D-01    |proj g|=  2.89461D-03
#
# At iterate   26    f= -9.45479D-01    |proj g|=  3.89966D-04
#
# At iterate   27    f= -9.45479D-01    |proj g|=  7.27307D-05
#
# At iterate   28    f= -9.45479D-01    |proj g|=  9.27036D-06
#
# At iterate   29    f= -9.45479D-01    |proj g|=  9.22595D-06
#
# At iterate   30    f= -9.45479D-01    |proj g|=  1.07581D-05
#
# At iterate   31    f= -9.45479D-01    |proj g|=  6.12732D-05
#
# At iterate   32    f= -9.45479D-01    |proj g|=  5.26912D-05
#
# At iterate   33    f= -9.45479D-01    |proj g|=  3.08198D-05
#
# At iterate   34    f= -9.45479D-01    |proj g|=  1.03140D-05
#
# At iterate   35    f= -9.45479D-01    |proj g|=  7.86038D-06
#
# At iterate   36    f= -9.45479D-01    |proj g|=  6.88338D-06
#
# At iterate   37    f= -9.45479D-01    |proj g|=  7.21645D-07
#
# At iterate   38    f= -9.45479D-01    |proj g|=  1.33227D-07
#
# At iterate   39    f= -9.45479D-01    |proj g|=  1.44329D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     39     44      1     0     0   1.443D-07  -9.455D-01
#   F = -0.94547900466560786
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.49777D-01    |proj g|=  3.31499D-01
#
# At iterate    1    f= -9.50022D-01    |proj g|=  1.10302D-02
#
# At iterate    2    f= -9.50024D-01    |proj g|=  9.75483D-03
#  This problem is unconstrained.
# At iterate    3    f= -9.50027D-01    |proj g|=  1.98596D-02
#
# At iterate    4    f= -9.50036D-01    |proj g|=  4.96746D-02
#
# At iterate    5    f= -9.50058D-01    |proj g|=  9.35546D-02
#
# At iterate    6    f= -9.50106D-01    |proj g|=  1.46650D-01
#
# At iterate    7    f= -9.50190D-01    |proj g|=  1.78784D-01
#
# At iterate    8    f= -9.50280D-01    |proj g|=  1.38370D-01
#
# At iterate    9    f= -9.50323D-01    |proj g|=  5.13857D-02
#
# At iterate   10    f= -9.50330D-01    |proj g|=  3.72593D-03
#
# At iterate   11    f= -9.50330D-01    |proj g|=  4.64454D-03
#
# At iterate   12    f= -9.50331D-01    |proj g|=  6.36864D-03
#
# At iterate   13    f= -9.50334D-01    |proj g|=  1.29519D-02
#
# At iterate   14    f= -9.50340D-01    |proj g|=  2.10592D-02
#
# At iterate   15    f= -9.50354D-01    |proj g|=  2.82563D-02
#
# At iterate   16    f= -9.50370D-01    |proj g|=  2.66772D-02
#
# At iterate   17    f= -9.50380D-01    |proj g|=  1.17699D-02
#
# At iterate   18    f= -9.50381D-01    |proj g|=  5.62235D-03
#
# At iterate   19    f= -9.50381D-01    |proj g|=  7.45615D-04
#
# At iterate   20    f= -9.50381D-01    |proj g|=  5.22382D-04
#
# At iterate   21    f= -9.50381D-01    |proj g|=  3.20399D-04
#
# At iterate   22    f= -9.50381D-01    |proj g|=  6.00053D-04
#
# At iterate   23    f= -9.50381D-01    |proj g|=  9.59377D-04
#
# At iterate   24    f= -9.50381D-01    |proj g|=  3.45890D-04
#
# At iterate   25    f= -9.50381D-01    |proj g|=  1.31117D-03
#
# At iterate   26    f= -9.50381D-01    |proj g|=  1.48237D-04
#
# At iterate   27    f= -9.50381D-01    |proj g|=  4.31399D-04
#
# At iterate   28    f= -9.50381D-01    |proj g|=  4.75830D-04
#
# At iterate   29    f= -9.50381D-01    |proj g|=  7.49401D-04
#
# At iterate   30    f= -9.50381D-01    |proj g|=  2.63656D-04
#
# At iterate   31    f= -9.50381D-01    |proj g|=  3.01537D-05
#
# At iterate   32    f= -9.50381D-01    |proj g|=  3.67817D-05
#
# At iterate   33    f= -9.50381D-01    |proj g|=  7.90035D-05
#
# At iterate   34    f= -9.50381D-01    |proj g|=  1.56919D-04
#
# At iterate   35    f= -9.50381D-01    |proj g|=  2.10909D-04
#
# At iterate   36    f= -9.50381D-01    |proj g|=  1.84741D-04
#
# At iterate   37    f= -9.50381D-01    |proj g|=  1.10567D-04
#
# At iterate   38    f= -9.50381D-01    |proj g|=  3.35842D-05
#
# At iterate   39    f= -9.50381D-01    |proj g|=  3.06422D-06
#
# At iterate   40    f= -9.50381D-01    |proj g|=  2.20934D-06
#
# At iterate   41    f= -9.50381D-01    |proj g|=  1.02141D-06
#
# At iterate   42    f= -9.50381D-01    |proj g|=  2.12053D-06
#
# At iterate   43    f= -9.50381D-01    |proj g|=  1.26898D-05
#
# At iterate   44    f= -9.50381D-01    |proj g|=  3.86358D-06
#
# At iterate   45    f= -9.50381D-01    |proj g|=  2.13163D-06
#
# At iterate   46    f= -9.50381D-01    |proj g|=  1.09912D-06
#
# At iterate   47    f= -9.50381D-01    |proj g|=  1.88738D-07
#
# At iterate   48    f= -9.50381D-01    |proj g|=  2.22045D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     48     54      1     0     0   2.220D-07  -9.504D-01
#   F = -0.95038139706819025
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.45155D-01    |proj g|=  3.36949D-01
#  This problem is unconstrained.
# At iterate    1    f= -9.45389D-01    |proj g|=  1.21874D-02
#
# At iterate    2    f= -9.45390D-01    |proj g|=  9.49646D-03
#
# At iterate    3    f= -9.45393D-01    |proj g|=  1.76624D-02
#
# At iterate    4    f= -9.45400D-01    |proj g|=  4.67031D-02
#
# At iterate    5    f= -9.45418D-01    |proj g|=  8.89865D-02
#
# At iterate    6    f= -9.45460D-01    |proj g|=  1.44376D-01
#
# At iterate    7    f= -9.45539D-01    |proj g|=  1.88582D-01
#
# At iterate    8    f= -9.45636D-01    |proj g|=  1.67871D-01
#
# At iterate    9    f= -9.45699D-01    |proj g|=  7.63184D-02
#
# At iterate   10    f= -9.45713D-01    |proj g|=  6.49348D-03
#
# At iterate   11    f= -9.45714D-01    |proj g|=  8.40918D-03
#
# At iterate   12    f= -9.45715D-01    |proj g|=  1.14466D-02
#
# At iterate   13    f= -9.45717D-01    |proj g|=  1.77860D-02
#
# At iterate   14    f= -9.45722D-01    |proj g|=  2.65586D-02
#
# At iterate   15    f= -9.45733D-01    |proj g|=  3.49140D-02
#
# At iterate   16    f= -9.45749D-01    |proj g|=  3.47558D-02
#
# At iterate   17    f= -9.45756D-01    |proj g|=  5.15805D-02
#
# At iterate   18    f= -9.45763D-01    |proj g|=  2.60160D-03
#
# At iterate   19    f= -9.45763D-01    |proj g|=  4.60998D-04
#
# At iterate   20    f= -9.45763D-01    |proj g|=  4.77840D-04
#
# At iterate   21    f= -9.45763D-01    |proj g|=  1.39401D-03
#
# At iterate   22    f= -9.45763D-01    |proj g|=  2.35798D-03
#
# At iterate   23    f= -9.45763D-01    |proj g|=  2.82826D-03
#
# At iterate   24    f= -9.45763D-01    |proj g|=  1.99876D-03
#
# At iterate   25    f= -9.45763D-01    |proj g|=  2.71039D-04
#
# At iterate   26    f= -9.45764D-01    |proj g|=  7.24942D-04
#
# At iterate   27    f= -9.45764D-01    |proj g|=  1.04505D-03
#
# At iterate   28    f= -9.45764D-01    |proj g|=  8.84770D-04
#
# At iterate   29    f= -9.45764D-01    |proj g|=  3.06311D-05
#
# At iterate   30    f= -9.45764D-01    |proj g|=  3.73257D-05
#
# At iterate   31    f= -9.45764D-01    |proj g|=  3.56160D-05
#
# At iterate   32    f= -9.45764D-01    |proj g|=  2.45692D-05
#
# At iterate   33    f= -9.45764D-01    |proj g|=  3.03313D-05
#
# At iterate   34    f= -9.45764D-01    |proj g|=  3.15414D-05
#
# At iterate   35    f= -9.45764D-01    |proj g|=  1.63203D-06
#
# At iterate   36    f= -9.45764D-01    |proj g|=  1.28786D-06
#
# At iterate   37    f= -9.45764D-01    |proj g|=  1.58762D-06
#
# At iterate   38    f= -9.45764D-01    |proj g|=  6.32827D-07
#
# At iterate   39    f= -9.45764D-01    |proj g|=  1.11022D-07
#
# At iterate   40    f= -9.45764D-01    |proj g|=  1.11022D-07
#
# At iterate   41    f= -9.45764D-01    |proj g|=  3.33067D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     41     48      1     0     0   3.331D-08  -9.458D-01
#   F = -0.94576358339051247
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.46057D-01    |proj g|=  3.39241D-01
#
# At iterate    1    f= -9.46294D-01    |proj g|=  1.24172D-02
#
# At iterate    2    f= -9.46295D-01    |proj g|=  9.41895D-03
#  This problem is unconstrained.
# At iterate    3    f= -9.46298D-01    |proj g|=  1.73636D-02
#
# At iterate    4    f= -9.46305D-01    |proj g|=  4.63392D-02
#
# At iterate    5    f= -9.46323D-01    |proj g|=  8.82932D-02
#
# At iterate    6    f= -9.46364D-01    |proj g|=  1.43390D-01
#
# At iterate    7    f= -9.46442D-01    |proj g|=  1.87346D-01
#
# At iterate    8    f= -9.46538D-01    |proj g|=  1.66801D-01
#
# At iterate    9    f= -9.46600D-01    |proj g|=  7.58470D-02
#
# At iterate   10    f= -9.46614D-01    |proj g|=  5.90628D-03
#
# At iterate   11    f= -9.46615D-01    |proj g|=  9.07985D-03
#
# At iterate   12    f= -9.46616D-01    |proj g|=  1.24450D-02
#
# At iterate   13    f= -9.46618D-01    |proj g|=  1.94166D-02
#
# At iterate   14    f= -9.46624D-01    |proj g|=  2.88469D-02
#
# At iterate   15    f= -9.46635D-01    |proj g|=  3.78604D-02
#
# At iterate   16    f= -9.46652D-01    |proj g|=  3.75897D-02
#
# At iterate   17    f= -9.46659D-01    |proj g|=  5.52771D-02
#
# At iterate   18    f= -9.46667D-01    |proj g|=  5.63075D-03
#
# At iterate   19    f= -9.46667D-01    |proj g|=  6.76570D-04
#
# At iterate   20    f= -9.46667D-01    |proj g|=  5.43909D-04
#
# At iterate   21    f= -9.46667D-01    |proj g|=  9.93572D-04
#
# At iterate   22    f= -9.46668D-01    |proj g|=  2.27066D-03
#
# At iterate   23    f= -9.46668D-01    |proj g|=  2.73558D-03
#
# At iterate   24    f= -9.46668D-01    |proj g|=  1.91850D-03
#
# At iterate   25    f= -9.46668D-01    |proj g|=  4.34064D-04
#
# At iterate   26    f= -9.46668D-01    |proj g|=  1.27873D-03
#
# At iterate   27    f= -9.46668D-01    |proj g|=  2.04206D-03
#
# At iterate   28    f= -9.46668D-01    |proj g|=  2.24483D-03
#
# At iterate   29    f= -9.46668D-01    |proj g|=  1.40403D-03
#
# At iterate   30    f= -9.46668D-01    |proj g|=  1.68632D-04
#
# At iterate   31    f= -9.46668D-01    |proj g|=  8.98170D-06
#
# At iterate   32    f= -9.46668D-01    |proj g|=  8.84848D-06
#
# At iterate   33    f= -9.46668D-01    |proj g|=  2.25486D-05
#
# At iterate   34    f= -9.46668D-01    |proj g|=  1.59428D-05
#
# At iterate   35    f= -9.46668D-01    |proj g|=  9.50351D-06
#
# At iterate   36    f= -9.46668D-01    |proj g|=  2.74225D-06
#
# At iterate   37    f= -9.46668D-01    |proj g|=  4.32987D-06
#
# At iterate   38    f= -9.46668D-01    |proj g|=  8.74856D-06
#
# At iterate   39    f= -9.46668D-01    |proj g|=  8.84848D-06
#
# At iterate   40    f= -9.46668D-01    |proj g|=  1.35891D-05
#
# At iterate   41    f= -9.46668D-01    |proj g|=  6.99441D-07
#
# At iterate   42    f= -9.46668D-01    |proj g|=  4.32987D-07
#
# At iterate   43    f= -9.46668D-01    |proj g|=  1.33227D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     43     51      1     0     0   1.332D-07  -9.467D-01
#   F = -0.94666824315923082
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.42846D-01    |proj g|=  3.38237D-01
#
# At iterate    1    f= -9.43087D-01    |proj g|=  1.20857D-02
#
# At iterate    2    f= -9.43089D-01    |proj g|=  9.33879D-03
#
# At iterate    3    f= -9.43092D-01    |proj g|=  1.80381D-02
#
# At iterate    4    f= -9.43099D-01    |proj g|=  4.72851D-02
#
# At iterate    5    f= -9.43118D-01    |proj g|=  8.98173D-02
#
# At iterate    6    f= -9.43162D-01    |proj g|=  1.44508D-01
#
# At iterate    7    f= -9.43242D-01    |proj g|=  1.85378D-01
#
# At iterate    8    f= -9.43337D-01    |proj g|=  1.59052D-01
#  This problem is unconstrained.
# At iterate    9    f= -9.43393D-01    |proj g|=  6.91003D-02
#
# At iterate   10    f= -9.43405D-01    |proj g|=  5.87524D-03
#
# At iterate   11    f= -9.43406D-01    |proj g|=  7.03418D-03
#
# At iterate   12    f= -9.43406D-01    |proj g|=  9.57940D-03
#
# At iterate   13    f= -9.43408D-01    |proj g|=  1.60797D-02
#
# At iterate   14    f= -9.43414D-01    |proj g|=  2.52973D-02
#
# At iterate   15    f= -9.43427D-01    |proj g|=  3.49411D-02
#
# At iterate   16    f= -9.43447D-01    |proj g|=  3.68936D-02
#
# At iterate   17    f= -9.43460D-01    |proj g|=  5.39519D-02
#
# At iterate   18    f= -9.43464D-01    |proj g|=  2.70418D-02
#
# At iterate   19    f= -9.43466D-01    |proj g|=  5.49483D-04
#
# At iterate   20    f= -9.43466D-01    |proj g|=  5.47040D-04
#
# At iterate   21    f= -9.43467D-01    |proj g|=  1.10555D-03
#
# At iterate   22    f= -9.43467D-01    |proj g|=  3.17546D-03
#
# At iterate   23    f= -9.43467D-01    |proj g|=  3.74987D-03
#
# At iterate   24    f= -9.43468D-01    |proj g|=  2.11857D-03
#
# At iterate   25    f= -9.43468D-01    |proj g|=  5.51648D-04
#
# At iterate   26    f= -9.43468D-01    |proj g|=  2.15339D-04
#
# At iterate   27    f= -9.43468D-01    |proj g|=  2.12541D-04
#
# At iterate   28    f= -9.43468D-01    |proj g|=  5.73552D-04
#
# At iterate   29    f= -9.43468D-01    |proj g|=  9.18043D-05
#
# At iterate   30    f= -9.43468D-01    |proj g|=  1.32228D-05
#
# At iterate   31    f= -9.43468D-01    |proj g|=  1.31561D-05
#
# At iterate   32    f= -9.43468D-01    |proj g|=  2.08944D-05
#
# At iterate   33    f= -9.43468D-01    |proj g|=  5.31908D-05
#
# At iterate   34    f= -9.43468D-01    |proj g|=  9.36362D-05
#
# At iterate   35    f= -9.43468D-01    |proj g|=  1.43674D-04
#
# At iterate   36    f= -9.43468D-01    |proj g|=  1.53744D-04
#
# At iterate   37    f= -9.43468D-01    |proj g|=  1.79567D-04
#
# At iterate   38    f= -9.43468D-01    |proj g|=  9.27369D-05
#
# At iterate   39    f= -9.43468D-01    |proj g|=  3.63265D-05
#
# At iterate   40    f= -9.43468D-01    |proj g|=  3.44169D-07
#
# At iterate   41    f= -9.43468D-01    |proj g|=  2.88658D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     41     46      1     0     0   2.887D-07  -9.435D-01
#   F = -0.94346803105165256
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.44950D-01    |proj g|=  3.39841D-01
#
# At iterate    1    f= -9.45187D-01    |proj g|=  1.24857D-02
#
# At iterate    2    f= -9.45188D-01    |proj g|=  8.91021D-03
#
# At iterate    3    f= -9.45191D-01    |proj g|=  1.70938D-02
#
# At iterate    4    f= -9.45198D-01    |proj g|=  4.58765D-02
#
# At iterate    5    f= -9.45215D-01    |proj g|=  8.74242D-02
#
# At iterate    6    f= -9.45256D-01    |proj g|=  1.42105D-01
#
# At iterate    7    f= -9.45332D-01    |proj g|=  1.85839D-01
#
# At iterate    8    f= -9.45427D-01    |proj g|=  1.65764D-01
#
# At iterate    9    f= -9.45488D-01    |proj g|=  7.56384D-02
#
# At iterate   10    f= -9.45502D-01    |proj g|=  5.80407D-03
#
# At iterate   11    f= -9.45504D-01    |proj g|=  9.18616D-03
#
# At iterate   12    f= -9.45504D-01    |proj g|=  1.26044D-02
#
# At iterate   13    f= -9.45506D-01    |proj g|=  1.97278D-02
#
# At iterate   14    f= -9.45512D-01    |proj g|=  2.94439D-02
#
# At iterate   15    f= -9.45524D-01    |proj g|=  3.92832D-02
#
# At iterate   16    f= -9.45542D-01    |proj g|=  4.03502D-02
#
# At iterate   17    f= -9.45550D-01    |proj g|=  6.10755D-02
#
# At iterate   18    f= -9.45559D-01    |proj g|=  1.04032D-02
#
# At iterate   19    f= -9.45560D-01    |proj g|=  1.07558D-03
#
# At iterate   20    f= -9.45560D-01    |proj g|=  7.58726D-04
#
# At iterate   21    f= -9.45560D-01    |proj g|=  1.21942D-03
#
# At iterate   22    f= -9.45560D-01    |proj g|=  3.44251D-03
#
# At iterate   23    f= -9.45560D-01    |proj g|=  4.74509D-03
#
# At iterate   24    f= -9.45561D-01    |proj g|=  4.22711D-03
#
# At iterate   25    f= -9.45561D-01    |proj g|=  2.51454D-03
#
# At iterate   26    f= -9.45561D-01    |proj g|=  7.36633D-05
#
# At iterate   27    f= -9.45562D-01    |proj g|=  2.45381D-04
#
# At iterate   28    f= -9.45562D-01    |proj g|=  3.13705D-04
#
# At iterate   29    f= -9.45562D-01    |proj g|=  1.09446D-04
#
# At iterate   30    f= -9.45562D-01    |proj g|=  4.97047D-05
#
# At iterate   31    f= -9.45562D-01    |proj g|=  1.59428D-05
#
# At iterate   32    f= -9.45562D-01    |proj g|=  3.36842D-05
#
# At iterate   33    f= -9.45562D-01    |proj g|=  2.94875D-05
#
# At iterate   34    f= -9.45562D-01    |proj g|=  1.29119D-05
#
# At iterate   35    f= -9.45562D-01    |proj g|=  4.54747D-05
#
# At iterate   36    f= -9.45562D-01    |proj g|=  6.02185D-05
#
# At iterate   37    f= -9.45562D-01    |proj g|=  2.48357D-05
#
# At iterate   38    f= -9.45562D-01    |proj g|=  6.23945D-06
#
# At iterate   39    f= -9.45562D-01    |proj g|=  3.21965D-07
#
# At iterate   40    f= -9.45562D-01    |proj g|=  2.55351D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     40     45      1     0     0   2.554D-07  -9.456D-01
#   F = -0.94556150685009577
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.44207D-01    |proj g|=  3.35743D-01
#
# At iterate    1    f= -9.44448D-01    |proj g|=  1.17777D-02
#
# At iterate    2    f= -9.44449D-01    |proj g|=  8.93763D-03
#
# At iterate    3    f= -9.44452D-01    |proj g|=  1.76747D-02
#
# At iterate    4    f= -9.44459D-01    |proj g|=  4.62811D-02
#  This problem is unconstrained.
# At iterate    5    f= -9.44478D-01    |proj g|=  8.79623D-02
#
# At iterate    6    f= -9.44520D-01    |proj g|=  1.41701D-01
#
# At iterate    7    f= -9.44598D-01    |proj g|=  1.82344D-01
#
# At iterate    8    f= -9.44691D-01    |proj g|=  1.57498D-01
#
# At iterate    9    f= -9.44747D-01    |proj g|=  6.91348D-02
#
# At iterate   10    f= -9.44758D-01    |proj g|=  6.63513D-03
#
# At iterate   11    f= -9.44759D-01    |proj g|=  6.09259D-03
#
# At iterate   12    f= -9.44760D-01    |proj g|=  8.20164D-03
#
# At iterate   13    f= -9.44762D-01    |proj g|=  1.34963D-02
#
# At iterate   14    f= -9.44767D-01    |proj g|=  2.12518D-02
#
# At iterate   15    f= -9.44778D-01    |proj g|=  2.87963D-02
#
# At iterate   16    f= -9.44793D-01    |proj g|=  2.92885D-02
#
# At iterate   17    f= -9.44800D-01    |proj g|=  4.95525D-02
#
# At iterate   18    f= -9.44806D-01    |proj g|=  1.47564D-02
#
# At iterate   19    f= -9.44806D-01    |proj g|=  2.71427D-04
#
# At iterate   20    f= -9.44806D-01    |proj g|=  3.18612D-04
#
# At iterate   21    f= -9.44806D-01    |proj g|=  1.05981D-03
#
# At iterate   22    f= -9.44806D-01    |proj g|=  1.72025D-03
#
# At iterate   23    f= -9.44807D-01    |proj g|=  2.13700D-03
#
# At iterate   24    f= -9.44807D-01    |proj g|=  1.06389D-03
#
# At iterate   25    f= -9.44807D-01    |proj g|=  3.93818D-04
#
# At iterate   26    f= -9.44807D-01    |proj g|=  1.89881D-04
#
# At iterate   27    f= -9.44807D-01    |proj g|=  4.59188D-05
#
# At iterate   28    f= -9.44807D-01    |proj g|=  9.18376D-05
#
# At iterate   29    f= -9.44807D-01    |proj g|=  9.03166D-05
#
# At iterate   30    f= -9.44807D-01    |proj g|=  1.23768D-04
#
# At iterate   31    f= -9.44807D-01    |proj g|=  7.00551D-06
#
# At iterate   32    f= -9.44807D-01    |proj g|=  7.77933D-05
#
# At iterate   33    f= -9.44807D-01    |proj g|=  5.26579D-05
#
# At iterate   34    f= -9.44807D-01    |proj g|=  1.03251D-06
#
# At iterate   35    f= -9.44807D-01    |proj g|=  1.12133D-06
#
# At iterate   36    f= -9.44807D-01    |proj g|=  4.77396D-07
#
# At iterate   37    f= -9.44807D-01    |proj g|=  3.33067D-07
#
# At iterate   38    f= -9.44807D-01    |proj g|=  1.39888D-06
#
# At iterate   39    f= -9.44807D-01    |proj g|=  1.38778D-06
#
# At iterate   40    f= -9.44807D-01    |proj g|=  1.33227D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     40     45      1     0     0   1.332D-07  -9.448D-01
#   F = -0.94480684142067817
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.42733D-01    |proj g|=  3.23885D-01
#
# At iterate    1    f= -9.42974D-01    |proj g|=  1.02162D-02
#
# At iterate    2    f= -9.42975D-01    |proj g|=  8.73980D-03
#
# At iterate    3    f= -9.42978D-01    |proj g|=  1.89468D-02
#
# At iterate    4    f= -9.42986D-01    |proj g|=  4.70817D-02
#
# At iterate    5    f= -9.43007D-01    |proj g|=  8.86191D-02
#
# At iterate    6    f= -9.43051D-01    |proj g|=  1.38580D-01
#
# At iterate    7    f= -9.43128D-01    |proj g|=  1.68229D-01
#
# At iterate    8    f= -9.43210D-01    |proj g|=  1.29109D-01
#
# At iterate    9    f= -9.43248D-01    |proj g|=  4.73152D-02
#
# At iterate   10    f= -9.43254D-01    |proj g|=  3.39647D-03
#
# At iterate   11    f= -9.43255D-01    |proj g|=  4.08882D-03
#  This problem is unconstrained.
# At iterate   12    f= -9.43255D-01    |proj g|=  5.59339D-03
#
# At iterate   13    f= -9.43258D-01    |proj g|=  1.15303D-02
#
# At iterate   14    f= -9.43264D-01    |proj g|=  1.86180D-02
#
# At iterate   15    f= -9.43275D-01    |proj g|=  2.42298D-02
#
# At iterate   16    f= -9.43288D-01    |proj g|=  2.17144D-02
#
# At iterate   17    f= -9.43294D-01    |proj g|=  9.83391D-04
#
# At iterate   18    f= -9.43294D-01    |proj g|=  5.90239D-04
#
# At iterate   19    f= -9.43295D-01    |proj g|=  1.31918D-03
#
# At iterate   20    f= -9.43295D-01    |proj g|=  1.07580D-03
#
# At iterate   21    f= -9.43295D-01    |proj g|=  8.36953D-04
#
# At iterate   22    f= -9.43295D-01    |proj g|=  1.66567D-04
#
# At iterate   23    f= -9.43295D-01    |proj g|=  1.61615D-04
#
# At iterate   24    f= -9.43295D-01    |proj g|=  5.06373D-04
#
# At iterate   25    f= -9.43295D-01    |proj g|=  2.48246D-05
#
# At iterate   26    f= -9.43295D-01    |proj g|=  7.60503D-06
#
# At iterate   27    f= -9.43295D-01    |proj g|=  4.28546D-06
#
# At iterate   28    f= -9.43295D-01    |proj g|=  5.00711D-06
#
# At iterate   29    f= -9.43295D-01    |proj g|=  2.10942D-07
#
# At iterate   30    f= -9.43295D-01    |proj g|=  5.55112D-08
#
# At iterate   31    f= -9.43295D-01    |proj g|=  5.55112D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     31     37      1     0     0   5.551D-08  -9.433D-01
#   F = -0.94329467630824892
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.43701D-01    |proj g|=  3.24465D-01
#
# At iterate    1    f= -9.43926D-01    |proj g|=  1.07704D-02
#
# At iterate    2    f= -9.43927D-01    |proj g|=  8.88514D-03
#
# At iterate    3    f= -9.43930D-01    |proj g|=  1.87653D-02
#
# At iterate    4    f= -9.43938D-01    |proj g|=  4.73768D-02
#
# At iterate    5    f= -9.43957D-01    |proj g|=  8.97140D-02
#
# At iterate    6    f= -9.44000D-01    |proj g|=  1.42650D-01
#
# At iterate    7    f= -9.44077D-01    |proj g|=  1.79429D-01
#
# At iterate    8    f= -9.44166D-01    |proj g|=  1.48208D-01
#
# At iterate    9    f= -9.44214D-01    |proj g|=  6.12946D-02
#
# At iterate   10    f= -9.44223D-01    |proj g|=  5.64936D-03
#
# At iterate   11    f= -9.44224D-01    |proj g|=  4.82673D-03
#
# At iterate   12    f= -9.44224D-01    |proj g|=  6.49798D-03
#
# At iterate   13    f= -9.44226D-01    |proj g|=  1.17627D-02
#
# At iterate   14    f= -9.44232D-01    |proj g|=  1.90566D-02
#
# At iterate   15    f= -9.44243D-01    |proj g|=  2.54445D-02
#
# At iterate   16    f= -9.44257D-01    |proj g|=  2.43045D-02
#
# At iterate   17    f= -9.44266D-01    |proj g|=  1.41282D-02
#
# At iterate   18    f= -9.44266D-01    |proj g|=  6.09102D-04
#
# At iterate   19    f= -9.44266D-01    |proj g|=  2.25464D-04
#
# At iterate   20    f= -9.44266D-01    |proj g|=  2.27685D-04
#
# At iterate   21    f= -9.44266D-01    |proj g|=  6.52511D-04
#
# At iterate   22    f= -9.44266D-01    |proj g|=  7.51310D-04
#
# At iterate   23    f= -9.44266D-01    |proj g|=  3.72213D-04
#
# At iterate   24    f= -9.44266D-01    |proj g|=  2.74891D-05
#
# At iterate   25    f= -9.44266D-01    |proj g|=  2.74891D-05
#
# At iterate   26    f= -9.44266D-01    |proj g|=  4.22218D-05
#
# At iterate   27    f= -9.44266D-01    |proj g|=  4.57301D-05
#
# At iterate   28    f= -9.44266D-01    |proj g|=  5.29132D-05
#
# At iterate   29    f= -9.44266D-01    |proj g|=  4.80727D-06
#
# At iterate   30    f= -9.44266D-01    |proj g|=  9.76996D-07
#  This problem is unconstrained.
# At iterate   31    f= -9.44266D-01    |proj g|=  1.24345D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     31     40      1     0     0   1.243D-06  -9.443D-01
#   F = -0.94426648248551581
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.46371D-01    |proj g|=  3.29511D-01
#
# At iterate    1    f= -9.46606D-01    |proj g|=  1.11380D-02
#
# At iterate    2    f= -9.46607D-01    |proj g|=  8.91842D-03
#
# At iterate    3    f= -9.46610D-01    |proj g|=  1.81205D-02
#
# At iterate    4    f= -9.46617D-01    |proj g|=  4.64580D-02
#
# At iterate    5    f= -9.46636D-01    |proj g|=  8.79527D-02
#
# At iterate    6    f= -9.46678D-01    |proj g|=  1.39950D-01
#
# At iterate    7    f= -9.46754D-01    |proj g|=  1.75732D-01
#
# At iterate    8    f= -9.46840D-01    |proj g|=  1.44504D-01
#  This problem is unconstrained.
# At iterate    9    f= -9.46886D-01    |proj g|=  5.92484D-02
#
# At iterate   10    f= -9.46894D-01    |proj g|=  5.30774D-03
#
# At iterate   11    f= -9.46895D-01    |proj g|=  4.76434D-03
#
# At iterate   12    f= -9.46895D-01    |proj g|=  6.43354D-03
#
# At iterate   13    f= -9.46898D-01    |proj g|=  1.17984D-02
#
# At iterate   14    f= -9.46903D-01    |proj g|=  1.91168D-02
#
# At iterate   15    f= -9.46914D-01    |proj g|=  2.56064D-02
#
# At iterate   16    f= -9.46928D-01    |proj g|=  2.45306D-02
#
# At iterate   17    f= -9.46937D-01    |proj g|=  1.61706D-02
#
# At iterate   18    f= -9.46937D-01    |proj g|=  8.24074D-04
#
# At iterate   19    f= -9.46937D-01    |proj g|=  2.16160D-04
#
# At iterate   20    f= -9.46937D-01    |proj g|=  2.23166D-04
#
# At iterate   21    f= -9.46937D-01    |proj g|=  4.77129D-04
#
# At iterate   22    f= -9.46938D-01    |proj g|=  8.21310D-04
#
# At iterate   23    f= -9.46938D-01    |proj g|=  8.92597D-04
#
# At iterate   24    f= -9.46938D-01    |proj g|=  5.00833D-04
#
# At iterate   25    f= -9.46938D-01    |proj g|=  5.38125D-05
#
# At iterate   26    f= -9.46938D-01    |proj g|=  2.90434D-05
#
# At iterate   27    f= -9.46938D-01    |proj g|=  4.81282D-05
#
# At iterate   28    f= -9.46938D-01    |proj g|=  6.77014D-05
#
# At iterate   29    f= -9.46938D-01    |proj g|=  5.52003D-05
#
# At iterate   30    f= -9.46938D-01    |proj g|=  2.29927D-05
#
# At iterate   31    f= -9.46938D-01    |proj g|=  6.13953D-06
#
# At iterate   32    f= -9.46938D-01    |proj g|=  6.97220D-06
#
# At iterate   33    f= -9.46938D-01    |proj g|=  4.10783D-07
#
# At iterate   34    f= -9.46938D-01    |proj g|=  1.99840D-07
#
# At iterate   35    f= -9.46938D-01    |proj g|=  1.44329D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     35     42      1     0     0   1.443D-07  -9.469D-01
#   F = -0.94693762392918623
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.48710D-01    |proj g|=  3.26065D-01
#
# At iterate    1    f= -9.48937D-01    |proj g|=  1.09234D-02
#
# At iterate    2    f= -9.48938D-01    |proj g|=  9.09179D-03
#
# At iterate    3    f= -9.48941D-01    |proj g|=  1.86707D-02
#
# At iterate    4    f= -9.48948D-01    |proj g|=  4.73173D-02
#
# At iterate    5    f= -9.48967D-01    |proj g|=  8.94964D-02
#
# At iterate    6    f= -9.49010D-01    |proj g|=  1.41944D-01
#
# At iterate    7    f= -9.49086D-01    |proj g|=  1.77309D-01
#
# At iterate    8    f= -9.49172D-01    |proj g|=  1.44317D-01
#
# At iterate    9    f= -9.49217D-01    |proj g|=  5.82801D-02
#
# At iterate   10    f= -9.49226D-01    |proj g|=  5.01151D-03
#
# At iterate   11    f= -9.49226D-01    |proj g|=  4.76368D-03
#
# At iterate   12    f= -9.49227D-01    |proj g|=  6.44939D-03
#
# At iterate   13    f= -9.49229D-01    |proj g|=  1.21040D-02
#
# At iterate   14    f= -9.49235D-01    |proj g|=  1.96609D-02
#
# At iterate   15    f= -9.49246D-01    |proj g|=  2.63945D-02
#
# At iterate   16    f= -9.49261D-01    |proj g|=  2.52776D-02
#
# At iterate   17    f= -9.49270D-01    |proj g|=  1.64541D-02
#
# At iterate   18    f= -9.49270D-01    |proj g|=  8.07687D-04
#
# At iterate   19    f= -9.49270D-01    |proj g|=  1.90015D-04
#
# At iterate   20    f= -9.49270D-01    |proj g|=  1.97586D-04
#
# At iterate   21    f= -9.49270D-01    |proj g|=  4.23539D-04
#
# At iterate   22    f= -9.49270D-01    |proj g|=  7.35612D-04
#
# At iterate   23    f= -9.49270D-01    |proj g|=  8.08598D-04
#
# At iterate   24    f= -9.49271D-01    |proj g|=  3.96638D-04
#
# At iterate   25    f= -9.49271D-01    |proj g|=  3.59823D-05
#
# At iterate   26    f= -9.49271D-01    |proj g|=  3.86691D-05
#
# At iterate   27    f= -9.49271D-01    |proj g|=  6.12621D-05
#
# At iterate   28    f= -9.49271D-01    |proj g|=  7.55729D-05
#
# At iterate   29    f= -9.49271D-01    |proj g|=  5.31353D-05
#
# At iterate   30    f= -9.49271D-01    |proj g|=  1.58429D-05
#
# At iterate   31    f= -9.49271D-01    |proj g|=  3.75255D-06
#
# At iterate   32    f= -9.49271D-01    |proj g|=  2.54241D-06
#
# At iterate   33    f= -9.49271D-01    |proj g|=  7.54952D-07
#
# At iterate   34    f= -9.49271D-01    |proj g|=  1.12133D-06
#
# At iterate   35    f= -9.49271D-01    |proj g|=  2.10942D-07
#
# At iterate   36    f= -9.49271D-01    |proj g|=  5.55112D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     36     42      1     0     0   5.551D-08  -9.493D-01
#   F = -0.94927053094404079
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.45267D-01    |proj g|=  3.12647D-01
#
# At iterate    1    f= -9.45483D-01    |proj g|=  9.53526D-03
#
# At iterate    2    f= -9.45484D-01    |proj g|=  8.79127D-03
#
# At iterate    3    f= -9.45488D-01    |proj g|=  2.00269D-02
#
# At iterate    4    f= -9.45496D-01    |proj g|=  4.85023D-02
#
# At iterate    5    f= -9.45516D-01    |proj g|=  9.10978D-02
#
# At iterate    6    f= -9.45561D-01    |proj g|=  1.41356D-01
#
# At iterate    7    f= -9.45637D-01    |proj g|=  1.69512D-01
#
# At iterate    8    f= -9.45716D-01    |proj g|=  1.27241D-01
#
# At iterate    9    f= -9.45752D-01    |proj g|=  4.49031D-02
#
# At iterate   10    f= -9.45758D-01    |proj g|=  3.89392D-03
#
# At iterate   11    f= -9.45758D-01    |proj g|=  5.26269D-03
#
# At iterate   12    f= -9.45759D-01    |proj g|=  7.33115D-03
#
# At iterate   13    f= -9.45762D-01    |proj g|=  1.49067D-02
#
# At iterate   14    f= -9.45768D-01    |proj g|=  2.36569D-02
#
# At iterate   15    f= -9.45782D-01    |proj g|=  3.10593D-02
#
# At iterate   16    f= -9.45798D-01    |proj g|=  2.82339D-02
#
# At iterate   17    f= -9.45807D-01    |proj g|=  9.94186D-03
#
# At iterate   18    f= -9.45807D-01    |proj g|=  3.50320D-04
#
# At iterate   19    f= -9.45807D-01    |proj g|=  5.78337D-04
#
# At iterate   20    f= -9.45807D-01    |proj g|=  2.60101D-03
#
# At iterate   21    f= -9.45807D-01    |proj g|=  2.21950D-03
#
# At iterate   22    f= -9.45808D-01    |proj g|=  1.52922D-04
#
# At iterate   23    f= -9.45808D-01    |proj g|=  1.45073D-04
#
# At iterate   24    f= -9.45808D-01    |proj g|=  1.32039D-04
#
# At iterate   25    f= -9.45808D-01    |proj g|=  9.63785D-05
#
# At iterate   26    f= -9.45808D-01    |proj g|=  6.73472D-04
#
# At iterate   27    f= -9.45808D-01    |proj g|=  2.88802D-04
#
# At iterate   28    f= -9.45808D-01    |proj g|=  2.58460D-05
#
# At iterate   29    f= -9.45808D-01    |proj g|=  2.53020D-05
#
# At iterate   30    f= -9.45808D-01    |proj g|=  2.53020D-05
#
# At iterate   31    f= -9.45808D-01    |proj g|=  7.69163D-05
#
# ...
#
# At iterate   26    f= -9.29094D-01    |proj g|=  2.36589D-05
#
# At iterate   27    f= -9.29094D-01    |proj g|=  3.13194D-05
#
# At iterate   28    f= -9.29094D-01    |proj g|=  5.55112D-06
#
# At iterate   29    f= -9.29094D-01    |proj g|=  1.90958D-06
#
# At iterate   30    f= -9.29094D-01    |proj g|=  4.85167D-06
#
# At iterate   31    f= -9.29094D-01    |proj g|=  2.10942D-07
#
# At iterate   32    f= -9.29094D-01    |proj g|=  2.10942D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     32     37      1     0     0   2.109D-07  -9.291D-01
#   F = -0.92909430759993894
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.24048D-01    |proj g|=  2.22929D-01
#
# At iterate    1    f= -9.24164D-01    |proj g|=  6.44386D-03
#
# At iterate    2    f= -9.24164D-01    |proj g|=  6.42706D-03
#
# At iterate    3    f= -9.24170D-01    |proj g|=  2.81810D-02
#
# At iterate    4    f= -9.24181D-01    |proj g|=  5.72163D-02
#
# At iterate    5    f= -9.24208D-01    |proj g|=  1.00039D-01
#
# At iterate    6    f= -9.24255D-01    |proj g|=  1.29290D-01
#
# At iterate    7    f= -9.24309D-01    |proj g|=  1.08418D-01
#
# At iterate    8    f= -9.24338D-01    |proj g|=  4.49973D-02
#
# At iterate    9    f= -9.24343D-01    |proj g|=  3.44096D-03
#
# At iterate   10    f= -9.24344D-01    |proj g|=  4.36537D-03
#
# At iterate   11    f= -9.24344D-01    |proj g|=  5.96843D-03
#
# At iterate   12    f= -9.24345D-01    |proj g|=  1.06008D-02
#
# At iterate   13    f= -9.24348D-01    |proj g|=  1.65189D-02
#
# At iterate   14    f= -9.24354D-01    |proj g|=  2.15764D-02
#
# At iterate   15    f= -9.24362D-01    |proj g|=  1.97188D-02
#
# At iterate   16    f= -9.24366D-01    |proj g|=  1.37454D-02
#
# At iterate   17    f= -9.24367D-01    |proj g|=  4.01990D-04
#
# At iterate   18    f= -9.24367D-01    |proj g|=  2.41174D-04
#
# At iterate   19    f= -9.24367D-01    |proj g|=  3.57503D-04
#
# At iterate   20    f= -9.24367D-01    |proj g|=  4.66238D-04
#
# At iterate   21    f= -9.24367D-01    |proj g|=  2.50611D-04
#
# At iterate   22    f= -9.24367D-01    |proj g|=  1.34337D-05
#
# At iterate   23    f= -9.24367D-01    |proj g|=  5.51781D-06
#
# At iterate   24    f= -9.24367D-01    |proj g|=  1.16573D-05
#
# At iterate   25    f= -9.24367D-01    |proj g|=  3.99680D-06
#
# At iterate   26    f= -9.24367D-01    |proj g|=  3.57492D-06
#
# At iterate   27    f= -9.24367D-01    |proj g|=  3.08642D-06
#
# At iterate   28    f= -9.24367D-01    |proj g|=  1.66533D-07
#
# At iterate   29    f= -9.24367D-01    |proj g|=  8.88178D-08
#
# At iterate   30    f= -9.24367D-01    |proj g|=  3.77476D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     30     36      1     0     0   3.775D-07  -9.244D-01
#   F = -0.92436719296711567
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.27535D-01    |proj g|=  2.24294D-01
#
# At iterate    1    f= -9.27651D-01    |proj g|=  6.54771D-03
#
# At iterate    2    f= -9.27651D-01    |proj g|=  6.53245D-03
#
# At iterate    3    f= -9.27657D-01    |proj g|=  2.74985D-02
#
# At iterate    4    f= -9.27667D-01    |proj g|=  5.61411D-02
#
# At iterate    5    f= -9.27693D-01    |proj g|=  9.88033D-02
#
# At iterate    6    f= -9.27739D-01    |proj g|=  1.29599D-01
#
# At iterate    7    f= -9.27793D-01    |proj g|=  1.11918D-01
#
# At iterate    8    f= -9.27824D-01    |proj g|=  4.82109D-02
#
# At iterate    9    f= -9.27830D-01    |proj g|=  3.64599D-03
#
# At iterate   10    f= -9.27831D-01    |proj g|=  5.09791D-03
#
# At iterate   11    f= -9.27831D-01    |proj g|=  6.95588D-03
#
# At iterate   12    f= -9.27832D-01    |proj g|=  1.16014D-02
#
# At iterate   13    f= -9.27835D-01    |proj g|=  1.76067D-02
#
# At iterate   14    f= -9.27840D-01    |proj g|=  2.27326D-02
#
# At iterate   15    f= -9.27848D-01    |proj g|=  2.08822D-02
#
# At iterate   16    f= -9.27852D-01    |proj g|=  1.61302D-02
#
# At iterate   17    f= -9.27853D-01    |proj g|=  1.41831D-03
#
# At iterate   18    f= -9.27853D-01    |proj g|=  2.50311D-04
#
# At iterate   19    f= -9.27853D-01    |proj g|=  4.12581D-04
#
# At iterate   20    f= -9.27853D-01    |proj g|=  6.44984D-04
#
# At iterate   21    f= -9.27853D-01    |proj g|=  9.91407D-04
#
# At iterate   22    f= -9.27853D-01    |proj g|=  1.04763D-03
#
# At iterate   23    f= -9.27853D-01    |proj g|=  4.45921D-04
#
# At iterate   24    f= -9.27853D-01    |proj g|=  6.30163D-05
#
# At iterate   25    f= -9.27853D-01    |proj g|=  2.25375D-05
#
# At iterate   26    f= -9.27853D-01    |proj g|=  1.98730D-05
#
# At iterate   27    f= -9.27853D-01    |proj g|=  1.96287D-05
#
# At iterate   28    f= -9.27853D-01    |proj g|=  2.62013D-06
#
# At iterate   29    f= -9.27853D-01    |proj g|=  6.55032D-07
#
# At iterate   30    f= -9.27853D-01    |proj g|=  1.47660D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     30     36      1     0     0   1.477D-06  -9.279D-01
#   F = -0.92785340015051720
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.23508D-01    |proj g|=  2.25867D-01
#
# At iterate    1    f= -9.23620D-01    |proj g|=  6.38104D-03
#
# At iterate    2    f= -9.23620D-01    |proj g|=  6.37040D-03
#
# At iterate    3    f= -9.23625D-01    |proj g|=  2.55456D-02
#
# At iterate    4    f= -9.23633D-01    |proj g|=  5.30517D-02
#
# At iterate    5    f= -9.23656D-01    |proj g|=  9.54900D-02
#
# At iterate    6    f= -9.23698D-01    |proj g|=  1.31910D-01
#
# At iterate    7    f= -9.23754D-01    |proj g|=  1.26625D-01
#
# At iterate    8    f= -9.23805D-01    |proj g|=  5.26012D-02
#
# At iterate    9    f= -9.23817D-01    |proj g|=  7.07688D-03
#
# At iterate   10    f= -9.23818D-01    |proj g|=  1.73802D-02
#
# At iterate   11    f= -9.23820D-01    |proj g|=  2.51215D-02
#
# At iterate   12    f= -9.23822D-01    |proj g|=  2.84346D-02
#
# At iterate   13    f= -9.23826D-01    |proj g|=  2.06803D-02
#
# At iterate   14    f= -9.23827D-01    |proj g|=  6.93314D-03
#
# At iterate   15    f= -9.23827D-01    |proj g|=  5.38347D-04
#
# At iterate   16    f= -9.23827D-01    |proj g|=  4.46387D-04
#
# At iterate   17    f= -9.23827D-01    |proj g|=  5.77494D-04
#
# At iterate   18    f= -9.23828D-01    |proj g|=  1.43774D-03
#
# At iterate   19    f= -9.23828D-01    |proj g|=  1.27752D-03
#
# At iterate   20    f= -9.23828D-01    |proj g|=  3.38360D-03
#
# At iterate   21    f= -9.23828D-01    |proj g|=  2.13647D-03
#
# At iterate   22    f= -9.23828D-01    |proj g|=  1.21616D-03
#
# At iterate   23    f= -9.23828D-01    |proj g|=  1.71566D-03
#
# At iterate   24    f= -9.23828D-01    |proj g|=  5.31608D-04
#
# At iterate   25    f= -9.23828D-01    |proj g|=  2.93021D-04
#
# At iterate   26    f= -9.23828D-01    |proj g|=  2.18070D-04
#
# At iterate   27    f= -9.23828D-01    |proj g|=  6.99263D-04
#
# At iterate   28    f= -9.23828D-01    |proj g|=  7.52243D-04
#
# At iterate   29    f= -9.23828D-01    |proj g|=  3.18356D-04
#
# At iterate   30    f= -9.23828D-01    |proj g|=  5.05151D-05
#
# At iterate   31    f= -9.23828D-01    |proj g|=  2.98095D-05
#
# At iterate   32    f= -9.23828D-01    |proj g|=  1.34925D-04
#
# At iterate   33    f= -9.23828D-01    |proj g|=  5.46119D-05
#
# At iterate   34    f= -9.23828D-01    |proj g|=  2.48468D-05
#
# At iterate   35    f= -9.23828D-01    |proj g|=  8.84848D-06
#
# At iterate   36    f= -9.23828D-01    |proj g|=  5.66214D-07
#
# At iterate   37    f= -9.23828D-01    |proj g|=  1.78746D-06
#
# At iterate   38    f= -9.23828D-01    |proj g|=  4.88498D-07
#
# At iterate   39    f= -9.23828D-01    |proj g|=  6.43929D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     39     46      1     0     0   6.439D-07  -9.238D-01
#   F = -0.92382809923211817
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.26701D-01    |proj g|=  2.26134D-01
#
# At iterate    1    f= -9.26811D-01    |proj g|=  6.35551D-03
#
# At iterate    2    f= -9.26812D-01    |proj g|=  6.34509D-03
#
# At iterate    3    f= -9.26816D-01    |proj g|=  2.50933D-02
#  This problem is unconstrained.
# At iterate    4    f= -9.26825D-01    |proj g|=  5.22554D-02
#
# At iterate    5    f= -9.26846D-01    |proj g|=  9.42760D-02
#
# At iterate    6    f= -9.26887D-01    |proj g|=  1.30946D-01
#
# At iterate    7    f= -9.26942D-01    |proj g|=  1.27093D-01
#
# At iterate    8    f= -9.26998D-01    |proj g|=  4.76287D-02
#
# At iterate    9    f= -9.27009D-01    |proj g|=  9.49608D-03
#
# At iterate   10    f= -9.27010D-01    |proj g|=  1.74887D-02
#
# At iterate   11    f= -9.27012D-01    |proj g|=  2.33590D-02
#
# At iterate   12    f= -9.27014D-01    |proj g|=  2.13149D-02
#
# At iterate   13    f= -9.27015D-01    |proj g|=  9.41843D-03
#
# At iterate   14    f= -9.27016D-01    |proj g|=  1.03507D-03
#
# At iterate   15    f= -9.27016D-01    |proj g|=  7.01750D-04
#
# At iterate   16    f= -9.27016D-01    |proj g|=  9.08817D-04
#
# At iterate   17    f= -9.27016D-01    |proj g|=  1.60580D-03
#
# At iterate   18    f= -9.27016D-01    |proj g|=  2.32417D-03
#
# At iterate   19    f= -9.27016D-01    |proj g|=  4.08616D-03
#
# At iterate   20    f= -9.27016D-01    |proj g|=  1.39662D-03
#
# At iterate   21    f= -9.27016D-01    |proj g|=  5.23481D-04
#
# At iterate   22    f= -9.27016D-01    |proj g|=  2.87881D-04
#
# At iterate   23    f= -9.27016D-01    |proj g|=  2.95097D-04
#
# At iterate   24    f= -9.27016D-01    |proj g|=  1.28305D-03
#
# At iterate   25    f= -9.27016D-01    |proj g|=  1.22414D-03
#
# At iterate   26    f= -9.27016D-01    |proj g|=  5.52947D-04
#
# At iterate   27    f= -9.27016D-01    |proj g|=  7.75846D-04
#
# At iterate   28    f= -9.27016D-01    |proj g|=  2.42251D-05
#
# At iterate   29    f= -9.27016D-01    |proj g|=  2.20490D-05
#
# At iterate   30    f= -9.27016D-01    |proj g|=  2.08833D-05
#
# At iterate   31    f= -9.27016D-01    |proj g|=  1.01430D-04
#
# At iterate   32    f= -9.27016D-01    |proj g|=  7.10765D-05
#
# At iterate   33    f= -9.27016D-01    |proj g|=  3.68483D-05
#
# At iterate   34    f= -9.27016D-01    |proj g|=  1.23013D-05
#
# At iterate   35    f= -9.27016D-01    |proj g|=  1.53655D-05
#
# At iterate   36    f= -9.27016D-01    |proj g|=  4.88498D-07
#
# At iterate   37    f= -9.27016D-01    |proj g|=  2.44249D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     37     45      1     0     0   2.442D-07  -9.270D-01
#   F = -0.92701609672842500
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.21154D-01    |proj g|=  2.27221D-01
#
# At iterate    1    f= -9.21268D-01    |proj g|=  6.41882D-03
#
# At iterate    2    f= -9.21269D-01    |proj g|=  6.40642D-03
#
# At iterate    3    f= -9.21274D-01    |proj g|=  2.59433D-02
#
# At iterate    4    f= -9.21283D-01    |proj g|=  5.36944D-02
#
# At iterate    5    f= -9.21306D-01    |proj g|=  9.60730D-02
#
# At iterate    6    f= -9.21349D-01    |proj g|=  1.30893D-01
#
# At iterate    7    f= -9.21405D-01    |proj g|=  1.22078D-01
#
# At iterate    8    f= -9.21446D-01    |proj g|=  5.52440D-02
#
# At iterate    9    f= -9.21456D-01    |proj g|=  2.56551D-03
#
# At iterate   10    f= -9.21457D-01    |proj g|=  1.29513D-02
#
# At iterate   11    f= -9.21458D-01    |proj g|=  1.91041D-02
#
# At iterate   12    f= -9.21460D-01    |proj g|=  2.72552D-02
#
# At iterate   13    f= -9.21465D-01    |proj g|=  3.37264D-02
#
# At iterate   14    f= -9.21472D-01    |proj g|=  3.02969D-02
#
# At iterate   15    f= -9.21476D-01    |proj g|=  1.56664D-02
#
# At iterate   16    f= -9.21477D-01    |proj g|=  2.28427D-03
#
# At iterate   17    f= -9.21477D-01    |proj g|=  4.35740D-04
#
# At iterate   18    f= -9.21477D-01    |proj g|=  5.54623D-04
#
# At iterate   19    f= -9.21477D-01    |proj g|=  2.04008D-03
#
# At iterate   20    f= -9.21477D-01    |proj g|=  2.87640D-03
#
# At iterate   21    f= -9.21477D-01    |proj g|=  3.98044D-03
#
# At iterate   22    f= -9.21478D-01    |proj g|=  2.62537D-03
#
# At iterate   23    f= -9.21478D-01    |proj g|=  1.74918D-03
#
# At iterate   24    f= -9.21478D-01    |proj g|=  6.52578D-04
#
# At iterate   25    f= -9.21478D-01    |proj g|=  1.31495D-04
#
# At iterate   26    f= -9.21478D-01    |proj g|=  2.95786D-04
#
# At iterate   27    f= -9.21478D-01    |proj g|=  5.83600D-04
#
# At iterate   28    f= -9.21478D-01    |proj g|=  8.09652D-04
#
# At iterate   29    f= -9.21478D-01    |proj g|=  5.80092D-04
#
# At iterate   30    f= -9.21478D-01    |proj g|=  8.63898D-04
#
# At iterate   31    f= -9.21478D-01    |proj g|=  1.54032D-04
#
# At iterate   32    f= -9.21478D-01    |proj g|=  1.91847D-05
#
# At iterate   33    f= -9.21478D-01    |proj g|=  9.96980D-06
#
# At iterate   34    f= -9.21478D-01    |proj g|=  9.12603D-06
#
# At iterate   35    f= -9.21478D-01    |proj g|=  4.20775D-06
#
# At iterate   36    f= -9.21478D-01    |proj g|=  1.03695D-05
#
# At iterate   37    f= -9.21478D-01    |proj g|=  3.40838D-06
#
# At iterate   38    f= -9.21478D-01    |proj g|=  2.96430D-06
#
# At iterate   39    f= -9.21478D-01    |proj g|=  2.60902D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     39     46      1     0     0   2.609D-06  -9.215D-01
#   F = -0.92147780081363373
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %% [markdown]
# Now, we will compare the predictions to the actual values.

# %%
test['n_passengers_pred'] = np.exp(pred)
test[['n_passengers', 'n_passengers_pred']].plot()
# Out:
# /var/folders/dl/nzqz9d4s48z5l005svj0w2sr0000gn/T/ipykernel_6494/2815816134.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['n_passengers_pred'] = np.exp(pred)
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# The predictions follow the actual values quite nicely. To get a more quantitative estimate of how good the predictions are, we can plot the histogram of the error, and we can calculate the root mean square error.

# %%
test['error'] = test.n_passengers - test.n_passengers_pred
test.error.hist()
# Out:
# /var/folders/dl/nzqz9d4s48z5l005svj0w2sr0000gn/T/ipykernel_6494/2639070760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['error'] = test.n_passengers - test.n_passengers_pred
# <AxesSubplot:>

# %%
rmse = np.sqrt(np.mean(np.square(test.error - np.mean(test.error))))
print (rmse)
# Out:
# 45.49081947884362

# %% [markdown]
# # Long-term Predictions
#
# Sometimes, we need to forecast more than just one time step ahead. This is can be addressed in two ways:
#
# - **A direct forecast**. This forecast model is designed in a way that it directly estimates the value of $y$ in a more distant future. For example, in the case of an autoregression model it can be formulated as:
#
# $$\hat{y}_{t+h} = \beta_0 + \sum^{p}_{i = 0}\,\beta_i\,y_{t} + e_{t+h}$$
#
#
# where $h$ is called the **prediction horizon**.
#
# - **An iterative (inductive) forecast**. This means we will perform a sequence of short-term predictions (one step ahead), where each prediction uses previous prediction estimates as if it were an actual value.

# %% [markdown]
# ## Word of caution with long-term predictions
#
# Regardless of whether iterative or direct forecast is used, the **predictability** of future values of any time series decreases rapidly with increases of the prediction horizon. How far into the future we can predict the time series values depends on many factors, most prominently:
#
#   - Amount and frequency of observations
#   - Strength of seasonality, trend and noisiness
#   - Forecasting method
#   - Domain specific factors
#
# There are multiple methods for estimating the maximum prediction horizon. For more details see: https://robjhyndman.com/papers/ijf25.pdf (De Gooijer & Hyndman, 2006).
#
# However, **long-term predictions should be avoided unless absolutely necessary**.

# %% [markdown]
# **EXERCISE 6**

# %% [markdown]
# Use the ARIMA model to forecast the number of passengers across the whole testing set (from the previous exercises). Restrict your analysis to use only the training set data when fitting the model, and use iterative forecasting. See what is the maximum prediction horizon for which the predictions hold. Adjust the order of the model, see if the predictions improve.

# %%
# Your work here

# %% [markdown]
# **Solution**
#
# Let's fit the model first, using the training data only.

# %%
arima = ARIMA(train.n_passengers_log.dropna().astype(float), order=(1,1,1))
arima_fit = arima.fit(disp=1, maxiter=100)
# Out:
# /Users/paulo/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# /Users/paulo/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/paulo/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.28378D-01    |proj g|=  1.08958D+01
#
# At iterate    1    f= -9.32826D-01    |proj g|=  9.51332D-01
#
# At iterate    2    f= -9.32860D-01    |proj g|=  1.39805D-02
#
# At iterate    3    f= -9.32860D-01    |proj g|=  1.39808D-02
#
# At iterate    4    f= -9.32860D-01    |proj g|=  2.54973D-02
#
# At iterate    5    f= -9.32860D-01    |proj g|=  5.87818D-02
#
# At iterate    6    f= -9.32861D-01    |proj g|=  1.17680D-01
#
# At iterate    7    f= -9.32862D-01    |proj g|=  2.09544D-01
#
# At iterate    8    f= -9.32866D-01    |proj g|=  3.58872D-01
#
# At iterate    9    f= -9.32875D-01    |proj g|=  5.93970D-01
#
# At iterate   10    f= -9.32898D-01    |proj g|=  9.52839D-01
#
# At iterate   11    f= -9.32954D-01    |proj g|=  1.44619D+00
#
# At iterate   12    f= -9.33074D-01    |proj g|=  1.95023D+00
#
# At iterate   13    f= -9.33261D-01    |proj g|=  2.05570D+00
#
# At iterate   14    f= -9.33430D-01    |proj g|=  1.42957D+00
#
# At iterate   15    f= -9.33506D-01    |proj g|=  5.41565D-01
#
# At iterate   16    f= -9.33520D-01    |proj g|=  6.47788D-02
#
# At iterate   17    f= -9.33521D-01    |proj g|=  5.03300D-03
#
# At iterate   18    f= -9.33521D-01    |proj g|=  1.71745D-03
#
# At iterate   19    f= -9.33521D-01    |proj g|=  6.06959D-05
#
# At iterate   20    f= -9.33521D-01    |proj g|=  8.88178D-07
#
# At iterate   21    f= -9.33521D-01    |proj g|=  4.47420D-06
#
# At iterate   22    f= -9.33521D-01    |proj g|=  4.50751D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     22     30      1     0     0   4.508D-06  -9.335D-01
#   F = -0.93352055638443066
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %% [markdown]
# Now we will forecast across the whole testing set. We will do out-of-sample forecasting by iteratively predicting the next point of the test series, and appending this prediction to the history. This approach for long-term forecasting is implemented in the `forecast` function.

# %%
pred,_,_ = arima_fit.forecast(steps=len(test))
test['n_passengers_pred_long'] = np.exp(pred)
test[['n_passengers', 'n_passengers_pred', 'n_passengers_pred_long']].plot()
# Out:
# /var/folders/dl/nzqz9d4s48z5l005svj0w2sr0000gn/T/ipykernel_6494/2365917033.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['n_passengers_pred_long'] = np.exp(pred)
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# As we can see, the predictions follow the overall trend, but are quite off.

# %% [markdown]
# Let's increase the order of the model, so that the order of AR will be equal to the period of the signal (12) and the order of MA will be equal to 5, which is one lag beyond the next lag where the autocorrelation of the signal is significant.

# %%
arima = ARIMA(train.n_passengers_log.dropna().astype(float), order=(12,1,6))
arima_fit = arima.fit(disp=1, maxiter=500)
pred,_,_ = arima_fit.forecast(steps=len(test))
test['n_passengers_pred_long'] = np.exp(pred)
test[['n_passengers', 'n_passengers_pred', 'n_passengers_pred_long']].plot()
# Out:
# /Users/paulo/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# /Users/paulo/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/paulo/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           19     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.70520D+00    |proj g|=  2.71428D+00
#  This problem is unconstrained.
# At iterate    1    f= -1.70619D+00    |proj g|=  1.45445D-01
#
# At iterate    2    f= -1.70624D+00    |proj g|=  1.27067D-01
#
# At iterate    3    f= -1.70645D+00    |proj g|=  2.72746D-02
#
# At iterate    4    f= -1.70662D+00    |proj g|=  3.76197D-02
#
# At iterate    5    f= -1.70712D+00    |proj g|=  5.12123D-02
#
# At iterate    6    f= -1.70787D+00    |proj g|=  8.97318D-02
#
# At iterate    7    f= -1.70993D+00    |proj g|=  1.12928D-01
#
# At iterate    8    f= -1.71214D+00    |proj g|=  1.41449D-01
#
# At iterate    9    f= -1.71351D+00    |proj g|=  1.72749D-01
#
# At iterate   10    f= -1.71421D+00    |proj g|=  1.80647D-02
#
# At iterate   11    f= -1.71432D+00    |proj g|=  2.16015D-02
#
# At iterate   12    f= -1.71439D+00    |proj g|=  1.72833D-02
#
# At iterate   13    f= -1.71500D+00    |proj g|=  2.86801D-02
#
# At iterate   14    f= -1.71501D+00    |proj g|=  1.23800D-01
#
# At iterate   15    f= -1.71538D+00    |proj g|=  3.65867D-02
#
# At iterate   16    f= -1.71563D+00    |proj g|=  1.91574D-02
#
# At iterate   17    f= -1.71572D+00    |proj g|=  7.43886D-02
#
# At iterate   18    f= -1.71586D+00    |proj g|=  3.68926D-02
#
# At iterate   19    f= -1.71604D+00    |proj g|=  1.79906D-02
#
# At iterate   20    f= -1.71639D+00    |proj g|=  3.22775D-02
#
# At iterate   21    f= -1.71676D+00    |proj g|=  4.38488D-02
#
# At iterate   22    f= -1.71725D+00    |proj g|=  6.29792D-02
#
# At iterate   23    f= -1.71738D+00    |proj g|=  2.38790D-02
#
# At iterate   24    f= -1.71746D+00    |proj g|=  1.59476D-02
#
# At iterate   25    f= -1.71758D+00    |proj g|=  1.00312D-02
#
# At iterate   26    f= -1.71783D+00    |proj g|=  4.06204D-02
#
# At iterate   27    f= -1.71810D+00    |proj g|=  8.24888D-01
#
# At iterate   28    f= -1.71851D+00    |proj g|=  1.02818D-01
#
# At iterate   29    f= -1.71886D+00    |proj g|=  4.26165D-02
#
# At iterate   30    f= -1.71908D+00    |proj g|=  1.34000D-01
#
# At iterate   31    f= -1.71913D+00    |proj g|=  2.90542D-02
#
# At iterate   32    f= -1.71925D+00    |proj g|=  2.73362D-01
#
# At iterate   33    f= -1.71935D+00    |proj g|=  2.69409D-01
#
# At iterate   34    f= -1.71938D+00    |proj g|=  3.99148D-01
#
# At iterate   35    f= -1.71946D+00    |proj g|=  1.98414D-01
#
# At iterate   36    f= -1.71948D+00    |proj g|=  1.88759D-02
#
# At iterate   37    f= -1.71948D+00    |proj g|=  5.76540D-02
#
# At iterate   38    f= -1.71949D+00    |proj g|=  1.35737D-01
#
# At iterate   39    f= -1.71951D+00    |proj g|=  2.02610D-01
#
# At iterate   40    f= -1.71953D+00    |proj g|=  1.98275D-01
#
# At iterate   41    f= -1.71957D+00    |proj g|=  4.38990D-01
#
# At iterate   42    f= -1.71966D+00    |proj g|=  2.74139D-01
#
# At iterate   43    f= -1.71985D+00    |proj g|=  1.41592D-01
#
# At iterate   44    f= -1.71993D+00    |proj g|=  2.80847D-01
#
# At iterate   45    f= -1.71999D+00    |proj g|=  2.25127D-01
#
# At iterate   46    f= -1.72002D+00    |proj g|=  2.95548D-01
#
# At iterate   47    f= -1.72004D+00    |proj g|=  2.93887D-01
#
# At iterate   48    f= -1.72007D+00    |proj g|=  7.26728D-02
#
# At iterate   49    f= -1.72010D+00    |proj g|=  1.35238D-01
#
# At iterate   50    f= -1.72015D+00    |proj g|=  3.55388D-01
#
# At iterate   51    f= -1.72022D+00    |proj g|=  5.32768D-01
#
# At iterate   52    f= -1.72031D+00    |proj g|=  4.93683D-01
#
# At iterate   53    f= -1.72031D+00    |proj g|=  5.16835D-01
#
# At iterate   54    f= -1.72032D+00    |proj g|=  4.19070D-01
#
# At iterate   55    f= -1.72037D+00    |proj g|=  2.12958D-01
#
# At iterate   56    f= -1.72038D+00    |proj g|=  2.44018D-02
#
# At iterate   57    f= -1.72039D+00    |proj g|=  5.63822D-02
#
# At iterate   58    f= -1.72040D+00    |proj g|=  1.66751D-01
#
# At iterate   59    f= -1.72043D+00    |proj g|=  3.22873D-01
#
# At iterate   60    f= -1.72049D+00    |proj g|=  4.91774D-01
#
# At iterate   61    f= -1.72059D+00    |proj g|=  5.71894D-01
#
# At iterate   62    f= -1.72066D+00    |proj g|=  3.86099D-01
#
# At iterate   63    f= -1.72072D+00    |proj g|=  2.25063D-01
#
# At iterate   64    f= -1.72076D+00    |proj g|=  8.87085D-02
#
# At iterate   65    f= -1.72077D+00    |proj g|=  6.28707D-02
#
# At iterate   66    f= -1.72078D+00    |proj g|=  1.35123D-01
#
# At iterate   67    f= -1.72080D+00    |proj g|=  2.08222D-01
#
# At iterate   68    f= -1.72082D+00    |proj g|=  1.39330D-01
#
# At iterate   69    f= -1.72082D+00    |proj g|=  1.01201D-01
#
# At iterate   70    f= -1.72084D+00    |proj g|=  1.36391D-01
#
# At iterate   71    f= -1.72086D+00    |proj g|=  1.12686D-01
#
# At iterate   72    f= -1.72087D+00    |proj g|=  1.95709D-02
#
# At iterate   73    f= -1.72089D+00    |proj g|=  1.45235D-02
#
# At iterate   74    f= -1.72092D+00    |proj g|=  2.17501D-01
#
# At iterate   75    f= -1.72095D+00    |proj g|=  2.63640D-01
#
# At iterate   76    f= -1.72101D+00    |proj g|=  2.16574D-01
#
# At iterate   77    f= -1.72105D+00    |proj g|=  2.73141D-01
#
# At iterate   78    f= -1.72108D+00    |proj g|=  3.13180D-02
#
# At iterate   79    f= -1.72110D+00    |proj g|=  5.31768D-02
#
# At iterate   80    f= -1.72116D+00    |proj g|=  3.11923D-02
#
# At iterate   81    f= -1.72124D+00    |proj g|=  2.95161D-02
#
# At iterate   82    f= -1.72133D+00    |proj g|=  1.59067D-01
#
# At iterate   83    f= -1.72142D+00    |proj g|=  1.47760D-01
#
# At iterate   84    f= -1.72142D+00    |proj g|=  1.28630D-01
#
# At iterate   85    f= -1.72146D+00    |proj g|=  8.41178D-03
#
# At iterate   86    f= -1.72146D+00    |proj g|=  8.14739D-03
#
# At iterate   87    f= -1.72147D+00    |proj g|=  2.86777D-02
#
# At iterate   88    f= -1.72148D+00    |proj g|=  1.69958D-02
#
# At iterate   89    f= -1.72148D+00    |proj g|=  5.69094D-03
#
# At iterate   90    f= -1.72149D+00    |proj g|=  6.71296D-03
#
# At iterate   91    f= -1.72149D+00    |proj g|=  1.07592D-01
#
# At iterate   92    f= -1.72151D+00    |proj g|=  4.24436D-02
#
# At iterate   93    f= -1.72151D+00    |proj g|=  1.32093D-02
#
# At iterate   94    f= -1.72152D+00    |proj g|=  1.41432D-02
#
# At iterate   95    f= -1.72153D+00    |proj g|=  1.35169D-02
#
# At iterate   96    f= -1.72153D+00    |proj g|=  1.88866D-02
#
# At iterate   97    f= -1.72154D+00    |proj g|=  7.17622D-03
#
# At iterate   98    f= -1.72156D+00    |proj g|=  1.48751D-02
#
# At iterate   99    f= -1.72157D+00    |proj g|=  1.34530D-01
#
# At iterate  100    f= -1.72161D+00    |proj g|=  3.31968D-02
#
# At iterate  101    f= -1.72164D+00    |proj g|=  5.04479D-02
#
# At iterate  102    f= -1.72168D+00    |proj g|=  5.22618D-02
#
# At iterate  103    f= -1.72168D+00    |proj g|=  1.07116D-01
#
# At iterate  104    f= -1.72169D+00    |proj g|=  6.62502D-02
#
# At iterate  105    f= -1.72170D+00    |proj g|=  1.80876D-02
#
# At iterate  106    f= -1.72170D+00    |proj g|=  3.14062D-02
#
# At iterate  107    f= -1.72173D+00    |proj g|=  4.86975D-02
#
# At iterate  108    f= -1.72174D+00    |proj g|=  1.24945D-01
#
# At iterate  109    f= -1.72178D+00    |proj g|=  6.00273D-02
#
# At iterate  110    f= -1.72182D+00    |proj g|=  1.43642D-02
#
# At iterate  111    f= -1.72184D+00    |proj g|=  1.38607D-02
#
# At iterate  112    f= -1.72185D+00    |proj g|=  5.71301D-03
#
# At iterate  113    f= -1.72186D+00    |proj g|=  1.06915D-02
#
# At iterate  114    f= -1.72187D+00    |proj g|=  6.27779D-02
#
# At iterate  115    f= -1.72188D+00    |proj g|=  3.90604D-02
#
# At iterate  116    f= -1.72188D+00    |proj g|=  8.11569D-03
#
# At iterate  117    f= -1.72188D+00    |proj g|=  8.72369D-03
#
# At iterate  118    f= -1.72188D+00    |proj g|=  5.24674D-02
#
# At iterate  119    f= -1.72189D+00    |proj g|=  4.20703D-02
#
# At iterate  120    f= -1.72189D+00    |proj g|=  2.30893D-02
#
# At iterate  121    f= -1.72190D+00    |proj g|=  1.02827D-02
#
# At iterate  122    f= -1.72191D+00    |proj g|=  1.66776D-02
#
# At iterate  123    f= -1.72191D+00    |proj g|=  8.04554D-02
#
# At iterate  124    f= -1.72193D+00    |proj g|=  4.85070D-02
#
# At iterate  125    f= -1.72196D+00    |proj g|=  1.31011D-02
#
# At iterate  126    f= -1.72197D+00    |proj g|=  2.99844D-02
#
# At iterate  127    f= -1.72199D+00    |proj g|=  4.83994D-02
#
# At iterate  128    f= -1.72200D+00    |proj g|=  1.88474D-02
#
# At iterate  129    f= -1.72200D+00    |proj g|=  6.24203D-03
#
# At iterate  130    f= -1.72201D+00    |proj g|=  1.03676D-02
#
# At iterate  131    f= -1.72201D+00    |proj g|=  8.97440D-02
#
# At iterate  132    f= -1.72202D+00    |proj g|=  1.34454D-02
#
# At iterate  133    f= -1.72202D+00    |proj g|=  2.51699D-02
#
# At iterate  134    f= -1.72203D+00    |proj g|=  2.26061D-02
#
# At iterate  135    f= -1.72203D+00    |proj g|=  2.04969D-02
#
# At iterate  136    f= -1.72207D+00    |proj g|=  1.14077D-01
# At iterate  137    f= -1.72209D+00    |proj g|=  5.93085D-02
#
# At iterate  138    f= -1.72215D+00    |proj g|=  2.52042D-02
#
# At iterate  139    f= -1.72217D+00    |proj g|=  3.25416D-02
#
# At iterate  140    f= -1.72219D+00    |proj g|=  5.32849D-02
#
# At iterate  141    f= -1.72221D+00    |proj g|=  3.17086D-02
#
# At iterate  142    f= -1.72223D+00    |proj g|=  1.41445D-02
#
# At iterate  143    f= -1.72228D+00    |proj g|=  1.25866D-02
#
# At iterate  144    f= -1.72228D+00    |proj g|=  5.65553D-02
#
# At iterate  145    f= -1.72231D+00    |proj g|=  3.78095D-02
#
# At iterate  146    f= -1.72231D+00    |proj g|=  2.51770D-02
#
# At iterate  147    f= -1.72233D+00    |proj g|=  2.47312D-02
#
# At iterate  148    f= -1.72235D+00    |proj g|=  1.30803D-02
#
# At iterate  149    f= -1.72236D+00    |proj g|=  2.37251D-02
#
# At iterate  150    f= -1.72236D+00    |proj g|=  4.04461D-03
#
# At iterate  151    f= -1.72236D+00    |proj g|=  3.93638D-03
#
# At iterate  152    f= -1.72237D+00    |proj g|=  1.24652D-02
#
# At iterate  153    f= -1.72239D+00    |proj g|=  2.76800D-02
#
# At iterate  154    f= -1.72241D+00    |proj g|=  8.06757D-03
#
# At iterate  155    f= -1.72243D+00    |proj g|=  7.16974D-02
#
# At iterate  156    f= -1.72244D+00    |proj g|=  2.36386D-02
#
# At iterate  157    f= -1.72245D+00    |proj g|=  4.83175D-02
#
# At iterate  158    f= -1.72245D+00    |proj g|=  2.09648D-02
#
# At iterate  159    f= -1.72245D+00    |proj g|=  1.12913D-02
#
# At iterate  160    f= -1.72245D+00    |proj g|=  9.07772D-03
#
# At iterate  161    f= -1.72246D+00    |proj g|=  4.35461D-03
#
# At iterate  162    f= -1.72247D+00    |proj g|=  9.18654D-03
#
# At iterate  163    f= -1.72247D+00    |proj g|=  5.54667D-02
#
# At iterate  164    f= -1.72248D+00    |proj g|=  5.14051D-02
#
# At iterate  165    f= -1.72250D+00    |proj g|=  7.97908D-03
#
# At iterate  166    f= -1.72250D+00    |proj g|=  8.67741D-03
#
# At iterate  167    f= -1.72251D+00    |proj g|=  1.18074D-02
#
# At iterate  168    f= -1.72252D+00    |proj g|=  2.89136D-02
#
# At iterate  169    f= -1.72253D+00    |proj g|=  2.19248D-02
#
# At iterate  170    f= -1.72253D+00    |proj g|=  5.33510D-02
#
# At iterate  171    f= -1.72253D+00    |proj g|=  3.71730D-02
#
# At iterate  172    f= -1.72253D+00    |proj g|=  9.98790D-03
#
# At iterate  173    f= -1.72254D+00    |proj g|=  8.29139D-03
#
# At iterate  174    f= -1.72254D+00    |proj g|=  8.19527D-03
#
# At iterate  175    f= -1.72257D+00    |proj g|=  2.11086D-02
#
# At iterate  176    f= -1.72258D+00    |proj g|=  3.39414D-02
#
# At iterate  177    f= -1.72260D+00    |proj g|=  1.63971D-02
#
# At iterate  178    f= -1.72262D+00    |proj g|=  1.57128D-02
#
# At iterate  179    f= -1.72264D+00    |proj g|=  1.35622D-02
#
# At iterate  180    f= -1.72266D+00    |proj g|=  7.50631D-03
#
# At iterate  181    f= -1.72267D+00    |proj g|=  2.56979D-02
#
# At iterate  182    f= -1.72268D+00    |proj g|=  5.67131D-03
#
# At iterate  183    f= -1.72268D+00    |proj g|=  3.40877D-02
#
# At iterate  184    f= -1.72269D+00    |proj g|=  2.67341D-02
#
# At iterate  185    f= -1.72269D+00    |proj g|=  5.04758D-03
#
# At iterate  186    f= -1.72269D+00    |proj g|=  3.71436D-03
#
# At iterate  187    f= -1.72269D+00    |proj g|=  5.69416D-03
#
# At iterate  188    f= -1.72270D+00    |proj g|=  2.00416D-02
#
# At iterate  189    f= -1.72271D+00    |proj g|=  2.90349D-02
#
# At iterate  190    f= -1.72272D+00    |proj g|=  6.77320D-03
#
# At iterate  191    f= -1.72272D+00    |proj g|=  5.36511D-03
#
# At iterate  192    f= -1.72273D+00    |proj g|=  2.71814D-03
#
# At iterate  193    f= -1.72273D+00    |proj g|=  3.25087D-03
#
# At iterate  194    f= -1.72273D+00    |proj g|=  5.83644D-03
#
# At iterate  195    f= -1.72273D+00    |proj g|=  1.14703D-02
#
# At iterate  196    f= -1.72273D+00    |proj g|=  2.11785D-02
#
# At iterate  197    f= -1.72274D+00    |proj g|=  1.09194D-02
#
# At iterate  198    f= -1.72274D+00    |proj g|=  1.25961D-02
#
# At iterate  199    f= -1.72274D+00    |proj g|=  1.40870D-02
#
# At iterate  200    f= -1.72274D+00    |proj g|=  1.81534D-02
#
# At iterate  201    f= -1.72275D+00    |proj g|=  5.33042D-03
#
# At iterate  202    f= -1.72275D+00    |proj g|=  3.98419D-03
#
# At iterate  203    f= -1.72275D+00    |proj g|=  1.12706D-02
#
# At iterate  204    f= -1.72276D+00    |proj g|=  8.02740D-03
#
# At iterate  205    f= -1.72277D+00    |proj g|=  2.93922D-02
#
# At iterate  206    f= -1.72277D+00    |proj g|=  1.96833D-02
#
# At iterate  207    f= -1.72278D+00    |proj g|=  3.52578D-03
#
# At iterate  208    f= -1.72278D+00    |proj g|=  3.49283D-03
#
# At iterate  209    f= -1.72278D+00    |proj g|=  1.27297D-01
#
# At iterate  210    f= -1.72279D+00    |proj g|=  3.36673D-02
#
# At iterate  211    f= -1.72279D+00    |proj g|=  7.98930D-03
#
# At iterate  212    f= -1.72279D+00    |proj g|=  3.22881D-02
#
# At iterate  213    f= -1.72279D+00    |proj g|=  2.86157D-02
#
# At iterate  214    f= -1.72280D+00    |proj g|=  5.42648D-03
#
# At iterate  215    f= -1.72280D+00    |proj g|=  4.93316D-03
#
# At iterate  216    f= -1.72280D+00    |proj g|=  1.09464D-02
#
# At iterate  217    f= -1.72280D+00    |proj g|=  2.17734D-02
#
# At iterate  218    f= -1.72281D+00    |proj g|=  2.38686D-02
#
# At iterate  219    f= -1.72281D+00    |proj g|=  1.65698D-02
#
# At iterate  220    f= -1.72281D+00    |proj g|=  1.62461D-02
#
# At iterate  221    f= -1.72282D+00    |proj g|=  4.24089D-02
#
# At iterate  222    f= -1.72282D+00    |proj g|=  2.20074D-02
#
# At iterate  223    f= -1.72282D+00    |proj g|=  4.73426D-03
#
# At iterate  224    f= -1.72282D+00    |proj g|=  4.31126D-03
#
# At iterate  225    f= -1.72282D+00    |proj g|=  2.38405D-02
#
# At iterate  226    f= -1.72282D+00    |proj g|=  1.18066D-02
#
# At iterate  227    f= -1.72282D+00    |proj g|=  3.87947D-03
#
# At iterate  228    f= -1.72282D+00    |proj g|=  2.08391D-03
#
# At iterate  229    f= -1.72282D+00    |proj g|=  8.31184D-03
#
# At iterate  230    f= -1.72283D+00    |proj g|=  1.35937D-02
#
# At iterate  231    f= -1.72283D+00    |proj g|=  2.94826D-02
#
# At iterate  232    f= -1.72283D+00    |proj g|=  5.88547D-03
#
# At iterate  233    f= -1.72283D+00    |proj g|=  3.61038D-03
#
# At iterate  234    f= -1.72283D+00    |proj g|=  2.34708D-03
#
# At iterate  235    f= -1.72283D+00    |proj g|=  2.82077D-03
#
# At iterate  236    f= -1.72283D+00    |proj g|=  1.42706D-02
#
# At iterate  237    f= -1.72283D+00    |proj g|=  7.33980D-03
#
# At iterate  238    f= -1.72283D+00    |proj g|=  6.07092D-03
#
# At iterate  239    f= -1.72283D+00    |proj g|=  4.35632D-03
#
# At iterate  240    f= -1.72283D+00    |proj g|=  1.53622D-03
#
# At iterate  241    f= -1.72283D+00    |proj g|=  3.06086D-03
#
# At iterate  242    f= -1.72283D+00    |proj g|=  9.65534D-03
#
# At iterate  243    f= -1.72283D+00    |proj g|=  3.67519D-03
#
# At iterate  244    f= -1.72283D+00    |proj g|=  1.59990D-03
#
# At iterate  245    f= -1.72283D+00    |proj g|=  1.57490D-03
#
# At iterate  246    f= -1.72283D+00    |proj g|=  6.88609D-03
#
# At iterate  247    f= -1.72283D+00    |proj g|=  3.14044D-03
#
# At iterate  248    f= -1.72283D+00    |proj g|=  3.14242D-03
#
# At iterate  249    f= -1.72284D+00    |proj g|=  1.00181D-02
#
# At iterate  250    f= -1.72284D+00    |proj g|=  1.49074D-03
#
# At iterate  251    f= -1.72284D+00    |proj g|=  1.66782D-02
#
# At iterate  252    f= -1.72284D+00    |proj g|=  2.89413D-03
#
# At iterate  253    f= -1.72284D+00    |proj g|=  2.24594D-03
#
# At iterate  254    f= -1.72284D+00    |proj g|=  1.36156D-02
#
# At iterate  255    f= -1.72284D+00    |proj g|=  1.53070D-02
#
# At iterate  256    f= -1.72284D+00    |proj g|=  1.00437D-02
#
# At iterate  257    f= -1.72284D+00    |proj g|=  5.48803D-03
#
# At iterate  258    f= -1.72284D+00    |proj g|=  1.15574D-02
#
# At iterate  259    f= -1.72284D+00    |proj g|=  1.91608D-02
#
# At iterate  260    f= -1.72284D+00    |proj g|=  1.00565D-02
#
# At iterate  261    f= -1.72284D+00    |proj g|=  8.57705D-03
#
# At iterate  262    f= -1.72284D+00    |proj g|=  1.24869D-02
#
# At iterate  263    f= -1.72284D+00    |proj g|=  1.08834D-02
#
# At iterate  264    f= -1.72284D+00    |proj g|=  6.31093D-03
#
# At iterate  265    f= -1.72284D+00    |proj g|=  2.27700D-03
#
# At iterate  266    f= -1.72284D+00    |proj g|=  7.26270D-03
#
# At iterate  267    f= -1.72284D+00    |proj g|=  4.50258D-03
#
# At iterate  268    f= -1.72284D+00    |proj g|=  7.14384D-04
#
# At iterate  269    f= -1.72284D+00    |proj g|=  3.61267D-03
#
# At iterate  270    f= -1.72284D+00    |proj g|=  2.86668D-03
# At iterate  271    f= -1.72284D+00    |proj g|=  6.15661D-03
#
# At iterate  272    f= -1.72284D+00    |proj g|=  4.03375D-03
#
# At iterate  273    f= -1.72284D+00    |proj g|=  1.66116D-03
#
# At iterate  274    f= -1.72284D+00    |proj g|=  4.64118D-03
#
# At iterate  275    f= -1.72284D+00    |proj g|=  5.70368D-03
#
# At iterate  276    f= -1.72284D+00    |proj g|=  1.75588D-03
#
# At iterate  277    f= -1.72284D+00    |proj g|=  5.30676D-03
#
# At iterate  278    f= -1.72284D+00    |proj g|=  2.60281D-03
#
# At iterate  279    f= -1.72284D+00    |proj g|=  2.97733D-03
#
# At iterate  280    f= -1.72284D+00    |proj g|=  1.69234D-03
#
# At iterate  281    f= -1.72284D+00    |proj g|=  8.86624D-04
#
# At iterate  282    f= -1.72284D+00    |proj g|=  1.86591D-03
#
# At iterate  283    f= -1.72284D+00    |proj g|=  2.22418D-03
#
# At iterate  284    f= -1.72284D+00    |proj g|=  3.56264D-03
#
# At iterate  285    f= -1.72284D+00    |proj g|=  1.46656D-03
#
# At iterate  286    f= -1.72284D+00    |proj g|=  1.68481D-03
#
# At iterate  287    f= -1.72284D+00    |proj g|=  8.16081D-04
#
# At iterate  288    f= -1.72284D+00    |proj g|=  4.37821D-03
#
# At iterate  289    f= -1.72284D+00    |proj g|=  7.18514D-04
#
# At iterate  290    f= -1.72284D+00    |proj g|=  1.06311D-03
#
# At iterate  291    f= -1.72284D+00    |proj g|=  2.43229D-02
#
# At iterate  292    f= -1.72284D+00    |proj g|=  5.98597D-03
#
# At iterate  293    f= -1.72284D+00    |proj g|=  2.03275D-03
#
# At iterate  294    f= -1.72284D+00    |proj g|=  8.64635D-03
#
# At iterate  295    f= -1.72284D+00    |proj g|=  9.68137D-03
#
# At iterate  296    f= -1.72284D+00    |proj g|=  1.27865D-02
#
# At iterate  297    f= -1.72284D+00    |proj g|=  4.14462D-03
#
# At iterate  298    f= -1.72284D+00    |proj g|=  1.75360D-03
#
# At iterate  299    f= -1.72284D+00    |proj g|=  2.78522D-03
#
# At iterate  300    f= -1.72284D+00    |proj g|=  7.47857D-03
#
# At iterate  301    f= -1.72284D+00    |proj g|=  3.55000D-03
#
# At iterate  302    f= -1.72284D+00    |proj g|=  9.95737D-04
#
# At iterate  303    f= -1.72284D+00    |proj g|=  4.05691D-03
#
# At iterate  304    f= -1.72284D+00    |proj g|=  3.06295D-03
#
# At iterate  305    f= -1.72284D+00    |proj g|=  2.45788D-03
#
# At iterate  306    f= -1.72284D+00    |proj g|=  3.75699D-04
#
# At iterate  307    f= -1.72284D+00    |proj g|=  1.78166D-03
#
# At iterate  308    f= -1.72284D+00    |proj g|=  2.02953D-03
#
# At iterate  309    f= -1.72284D+00    |proj g|=  6.42664D-04
#
# At iterate  310    f= -1.72284D+00    |proj g|=  3.62994D-03
#
# At iterate  311    f= -1.72284D+00    |proj g|=  2.60527D-03
#
# At iterate  312    f= -1.72284D+00    |proj g|=  1.49154D-03
#
# At iterate  313    f= -1.72284D+00    |proj g|=  3.49167D-03
#
# At iterate  314    f= -1.72284D+00    |proj g|=  6.32050D-04
#
# At iterate  315    f= -1.72284D+00    |proj g|=  2.37905D-03
#
# At iterate  316    f= -1.72284D+00    |proj g|=  5.34979D-03
#
# At iterate  317    f= -1.72284D+00    |proj g|=  1.23510D-03
#
# At iterate  318    f= -1.72284D+00    |proj g|=  3.83003D-03
#
# At iterate  319    f= -1.72284D+00    |proj g|=  4.92806D-04
#
# At iterate  320    f= -1.72284D+00    |proj g|=  5.75029D-04
#
# At iterate  321    f= -1.72284D+00    |proj g|=  3.99989D-03
#
# At iterate  322    f= -1.72284D+00    |proj g|=  2.42095D-03
#
# At iterate  323    f= -1.72284D+00    |proj g|=  7.63545D-04
#
# At iterate  324    f= -1.72284D+00    |proj g|=  1.68050D-03
#
# At iterate  325    f= -1.72284D+00    |proj g|=  6.19482D-04
#
# At iterate  326    f= -1.72284D+00    |proj g|=  1.28857D-03
#
# At iterate  327    f= -1.72284D+00    |proj g|=  1.61682D-03
#
# At iterate  328    f= -1.72284D+00    |proj g|=  1.88050D-04
#
# At iterate  329    f= -1.72284D+00    |proj g|=  2.33391D-04
#
# At iterate  330    f= -1.72284D+00    |proj g|=  1.18165D-03
#
# At iterate  331    f= -1.72284D+00    |proj g|=  1.61435D-03
#
# At iterate  332    f= -1.72284D+00    |proj g|=  1.11344D-03
#
# At iterate  333    f= -1.72284D+00    |proj g|=  6.75369D-03
#
# At iterate  334    f= -1.72284D+00    |proj g|=  1.10203D-03
#
# At iterate  335    f= -1.72284D+00    |proj g|=  1.57530D-03
#
# At iterate  336    f= -1.72284D+00    |proj g|=  8.51685D-03
#
# At iterate  337    f= -1.72284D+00    |proj g|=  2.45701D-03
#
# At iterate  338    f= -1.72284D+00    |proj g|=  6.81077D-04
#
# At iterate  339    f= -1.72284D+00    |proj g|=  1.14602D-03
#
# At iterate  340    f= -1.72284D+00    |proj g|=  4.49418D-04
#
# At iterate  341    f= -1.72284D+00    |proj g|=  4.89142D-04
#
# At iterate  342    f= -1.72284D+00    |proj g|=  4.45370D-03
#
# At iterate  343    f= -1.72284D+00    |proj g|=  3.72600D-03
#
# At iterate  344    f= -1.72284D+00    |proj g|=  3.43143D-03
#
# At iterate  345    f= -1.72284D+00    |proj g|=  1.73745D-03
#
# At iterate  346    f= -1.72284D+00    |proj g|=  4.21474D-03
#
# At iterate  347    f= -1.72284D+00    |proj g|=  1.74929D-03
#
# At iterate  348    f= -1.72284D+00    |proj g|=  4.24261D-04
#
# At iterate  349    f= -1.72284D+00    |proj g|=  3.80369D-03
#
# At iterate  350    f= -1.72284D+00    |proj g|=  3.83877D-03
#
# At iterate  351    f= -1.72284D+00    |proj g|=  1.98883D-03
#
# At iterate  352    f= -1.72284D+00    |proj g|=  3.71658D-04
#
# At iterate  353    f= -1.72284D+00    |proj g|=  4.21885D-04
#
# At iterate  354    f= -1.72284D+00    |proj g|=  1.82121D-04
#
# At iterate  355    f= -1.72284D+00    |proj g|=  5.82254D-03
#
# At iterate  356    f= -1.72284D+00    |proj g|=  2.45812D-03
#
# At iterate  357    f= -1.72284D+00    |proj g|=  1.29321D-03
#
# At iterate  358    f= -1.72284D+00    |proj g|=  1.15146D-03
#
# At iterate  359    f= -1.72284D+00    |proj g|=  4.44644D-04
#
# At iterate  360    f= -1.72284D+00    |proj g|=  5.75273D-04
#
# At iterate  361    f= -1.72284D+00    |proj g|=  1.64322D-03
#
# At iterate  362    f= -1.72284D+00    |proj g|=  1.21443D-03
#
# At iterate  363    f= -1.72284D+00    |proj g|=  2.93121D-04
#
# At iterate  364    f= -1.72284D+00    |proj g|=  1.04190D-03
#
# At iterate  365    f= -1.72284D+00    |proj g|=  1.17659D-03
#
# At iterate  366    f= -1.72284D+00    |proj g|=  8.83094D-04
#
# At iterate  367    f= -1.72284D+00    |proj g|=  6.54499D-04
#
# At iterate  368    f= -1.72284D+00    |proj g|=  4.33404D-03
#
# At iterate  369    f= -1.72284D+00    |proj g|=  3.49294D-03
#
# At iterate  370    f= -1.72284D+00    |proj g|=  2.79015D-03
#
# At iterate  371    f= -1.72284D+00    |proj g|=  1.38836D-03
#
# At iterate  372    f= -1.72284D+00    |proj g|=  3.79430D-04
#
# At iterate  373    f= -1.72284D+00    |proj g|=  1.27949D-03
#
# At iterate  374    f= -1.72284D+00    |proj g|=  2.18225D-04
#
# At iterate  375    f= -1.72284D+00    |proj g|=  4.14668D-04
#
# At iterate  376    f= -1.72284D+00    |proj g|=  1.06612D-03
#
# At iterate  377    f= -1.72284D+00    |proj g|=  1.46483D-03
#
# At iterate  378    f= -1.72284D+00    |proj g|=  1.27691D-03
#
# At iterate  379    f= -1.72284D+00    |proj g|=  4.35667D-03
#
# At iterate  380    f= -1.72284D+00    |proj g|=  4.23712D-03
#
# At iterate  381    f= -1.72284D+00    |proj g|=  2.42153D-03
#
# At iterate  382    f= -1.72284D+00    |proj g|=  1.27638D-03
#
# At iterate  383    f= -1.72284D+00    |proj g|=  1.34910D-03
#
# At iterate  384    f= -1.72284D+00    |proj g|=  4.85256D-04
#
# At iterate  385    f= -1.72284D+00    |proj g|=  7.16804D-04
#
# At iterate  386    f= -1.72284D+00    |proj g|=  2.13829D-04
#
# At iterate  387    f= -1.72284D+00    |proj g|=  2.18758D-04
#
# At iterate  388    f= -1.72284D+00    |proj g|=  8.44680D-04
#
# At iterate  389    f= -1.72284D+00    |proj g|=  9.41114D-04
#
# At iterate  390    f= -1.72284D+00    |proj g|=  2.43627D-04
#
# At iterate  391    f= -1.72284D+00    |proj g|=  4.30678D-04
#
# At iterate  392    f= -1.72284D+00    |proj g|=  3.30913D-04
#
# At iterate  393    f= -1.72284D+00    |proj g|=  2.06701D-04
#
# At iterate  394    f= -1.72284D+00    |proj g|=  1.69669D-03
#
# At iterate  395    f= -1.72284D+00    |proj g|=  7.61124D-04
#
# At iterate  396    f= -1.72284D+00    |proj g|=  1.13836D-03
#
# At iterate  397    f= -1.72284D+00    |proj g|=  1.64293D-03
#
# At iterate  398    f= -1.72284D+00    |proj g|=  8.62421D-04
#
# At iterate  399    f= -1.72284D+00    |proj g|=  2.07754D-03
#
# At iterate  400    f= -1.72284D+00    |proj g|=  2.35270D-03
#
# At iterate  401    f= -1.72284D+00    |proj g|=  1.25402D-03
#
# At iterate  402    f= -1.72284D+00    |proj g|=  1.81037D-03
#
# At iterate  403    f= -1.72284D+00    |proj g|=  3.02125D-03
# At iterate  404    f= -1.72284D+00    |proj g|=  1.37401D-03
#
# At iterate  405    f= -1.72284D+00    |proj g|=  3.79210D-03
#
# At iterate  406    f= -1.72284D+00    |proj g|=  1.74354D-03
#
# At iterate  407    f= -1.72284D+00    |proj g|=  2.73048D-03
#
# At iterate  408    f= -1.72284D+00    |proj g|=  1.19151D-03
#
# At iterate  409    f= -1.72284D+00    |proj g|=  8.57114D-04
#
# At iterate  410    f= -1.72284D+00    |proj g|=  3.39406D-03
#
# At iterate  411    f= -1.72284D+00    |proj g|=  1.49338D-03
#
# At iterate  412    f= -1.72284D+00    |proj g|=  5.57283D-03
#
# At iterate  413    f= -1.72284D+00    |proj g|=  2.03528D-03
#
# At iterate  414    f= -1.72284D+00    |proj g|=  1.45555D-03
#
# At iterate  415    f= -1.72284D+00    |proj g|=  2.88989D-03
#
# At iterate  416    f= -1.72284D+00    |proj g|=  8.35065D-04
#
# At iterate  417    f= -1.72284D+00    |proj g|=  5.29443D-04
#
# At iterate  418    f= -1.72284D+00    |proj g|=  2.96401D-03
#
# At iterate  419    f= -1.72284D+00    |proj g|=  3.13327D-04
#
# At iterate  420    f= -1.72284D+00    |proj g|=  3.99036D-04
#
# At iterate  421    f= -1.72284D+00    |proj g|=  3.64431D-03
#
# At iterate  422    f= -1.72284D+00    |proj g|=  2.97864D-03
#
# At iterate  423    f= -1.72284D+00    |proj g|=  2.66067D-03
#
# At iterate  424    f= -1.72284D+00    |proj g|=  4.09990D-03
#
# At iterate  425    f= -1.72284D+00    |proj g|=  2.70384D-03
#
# At iterate  426    f= -1.72284D+00    |proj g|=  1.25504D-03
#
# At iterate  427    f= -1.72284D+00    |proj g|=  1.07692D-03
#
# At iterate  428    f= -1.72284D+00    |proj g|=  7.87326D-04
#
# At iterate  429    f= -1.72284D+00    |proj g|=  6.37512D-04
#
# At iterate  430    f= -1.72284D+00    |proj g|=  1.13527D-03
#
# At iterate  431    f= -1.72284D+00    |proj g|=  8.90710D-04
#
# At iterate  432    f= -1.72284D+00    |proj g|=  1.12230D-03
#
# At iterate  433    f= -1.72284D+00    |proj g|=  2.32316D-03
#
# At iterate  434    f= -1.72284D+00    |proj g|=  1.60418D-03
#
# At iterate  435    f= -1.72284D+00    |proj g|=  7.01594D-04
#
# At iterate  436    f= -1.72284D+00    |proj g|=  1.20703D-03
#
# At iterate  437    f= -1.72284D+00    |proj g|=  1.27003D-03
#
# At iterate  438    f= -1.72284D+00    |proj g|=  1.49729D-03
#
# At iterate  439    f= -1.72284D+00    |proj g|=  5.47518D-04
#
# At iterate  440    f= -1.72284D+00    |proj g|=  7.23688D-04
#
# At iterate  441    f= -1.72284D+00    |proj g|=  7.57683D-04
#
# At iterate  442    f= -1.72284D+00    |proj g|=  1.32796D-03
#
# At iterate  443    f= -1.72284D+00    |proj g|=  2.02638D-04
#
# At iterate  444    f= -1.72284D+00    |proj g|=  3.73896D-03
#
# At iterate  445    f= -1.72284D+00    |proj g|=  4.29661D-03
#
# At iterate  446    f= -1.72284D+00    |proj g|=  9.34697D-04
#
# At iterate  447    f= -1.72284D+00    |proj g|=  1.54232D-04
#
# At iterate  448    f= -1.72284D+00    |proj g|=  2.94365D-04
#
# At iterate  449    f= -1.72284D+00    |proj g|=  4.14211D-03
#
# At iterate  450    f= -1.72284D+00    |proj g|=  3.86364D-03
#
# At iterate  451    f= -1.72284D+00    |proj g|=  1.66207D-03
#
# At iterate  452    f= -1.72284D+00    |proj g|=  2.97073D-04
#
# At iterate  453    f= -1.72284D+00    |proj g|=  4.27303D-04
#
# At iterate  454    f= -1.72284D+00    |proj g|=  1.94766D-03
#
# At iterate  455    f= -1.72284D+00    |proj g|=  3.51807D-04
#
# At iterate  456    f= -1.72284D+00    |proj g|=  5.21183D-04
#
# At iterate  457    f= -1.72284D+00    |proj g|=  3.68867D-03
#
# At iterate  458    f= -1.72284D+00    |proj g|=  1.70468D-03
#
# At iterate  459    f= -1.72284D+00    |proj g|=  1.26787D-04
#
# At iterate  460    f= -1.72284D+00    |proj g|=  1.72484D-04
#
# At iterate  461    f= -1.72284D+00    |proj g|=  1.53588D-04
#
# At iterate  462    f= -1.72284D+00    |proj g|=  6.41198D-04
#
# At iterate  463    f= -1.72284D+00    |proj g|=  1.04430D-03
#
# At iterate  464    f= -1.72284D+00    |proj g|=  5.59752D-04
#
# At iterate  465    f= -1.72284D+00    |proj g|=  1.09375D-03
#
# At iterate  466    f= -1.72284D+00    |proj g|=  8.14926D-04
#
# At iterate  467    f= -1.72284D+00    |proj g|=  7.09632D-04
#
# At iterate  468    f= -1.72284D+00    |proj g|=  5.06528D-04
#
# At iterate  469    f= -1.72284D+00    |proj g|=  2.64411D-04
#
# At iterate  470    f= -1.72284D+00    |proj g|=  7.42051D-04
#
# At iterate  471    f= -1.72284D+00    |proj g|=  6.44906D-04
#
# At iterate  472    f= -1.72284D+00    |proj g|=  1.07825D-04
#
# At iterate  473    f= -1.72284D+00    |proj g|=  1.18032D-03
#
# At iterate  474    f= -1.72284D+00    |proj g|=  1.25595D-03
#
# At iterate  475    f= -1.72284D+00    |proj g|=  1.89955D-03
#
# At iterate  476    f= -1.72284D+00    |proj g|=  7.50444D-04
#
# At iterate  477    f= -1.72284D+00    |proj g|=  8.48877D-04
#
# At iterate  478    f= -1.72284D+00    |proj g|=  6.92113D-04
#
# At iterate  479    f= -1.72284D+00    |proj g|=  3.93552D-04
#
# At iterate  480    f= -1.72284D+00    |proj g|=  4.61076D-04
#
# At iterate  481    f= -1.72284D+00    |proj g|=  1.01037D-03
#
# At iterate  482    f= -1.72284D+00    |proj g|=  1.00377D-03
#
# At iterate  483    f= -1.72284D+00    |proj g|=  6.29519D-04
#
# At iterate  484    f= -1.72284D+00    |proj g|=  7.16849D-04
#
# At iterate  485    f= -1.72284D+00    |proj g|=  1.60896D-03
#
# At iterate  486    f= -1.72284D+00    |proj g|=  4.65361D-04
#
# At iterate  487    f= -1.72284D+00    |proj g|=  1.10409D-03
#
# At iterate  488    f= -1.72284D+00    |proj g|=  9.08917D-04
#
# At iterate  489    f= -1.72284D+00    |proj g|=  1.16591D-03
#
# At iterate  490    f= -1.72284D+00    |proj g|=  4.99472D-03
#
# At iterate  491    f= -1.72284D+00    |proj g|=  2.36338D-03
#
# At iterate  492    f= -1.72284D+00    |proj g|=  3.75500D-04
#
# At iterate  493    f= -1.72284D+00    |proj g|=  6.82077D-04
#
# At iterate  494    f= -1.72284D+00    |proj g|=  2.67313D-03
#
# At iterate  495    f= -1.72284D+00    |proj g|=  5.98233D-04
#
# At iterate  496    f= -1.72284D+00    |proj g|=  2.20075D-03
#
# At iterate  497    f= -1.72284D+00    |proj g|=  2.39770D-03
#
# At iterate  498    f= -1.72284D+00    |proj g|=  1.48905D-03
#
# At iterate  499    f= -1.72284D+00    |proj g|=  6.54965D-04
#
# At iterate  500    f= -1.72284D+00    |proj g|=  3.05933D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    19    500    604      1     0     0   3.059D-04  -1.723D+00
#   F =  -1.7228426712515867
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# /Users/paulo/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /var/folders/dl/nzqz9d4s48z5l005svj0w2sr0000gn/T/ipykernel_6494/2370751197.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['n_passengers_pred_long'] = np.exp(pred)
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# As we can see, the predictions are much better, but still worse that the in-sample prediction from the previous exercise. By increasing the order of our model, the model takes into account more of the signal's past. It also added more "flexibility" to the model, so it can now fit the signal better. Feel free to adjust the order of the model to obtain the best predictions.

# %% [markdown]
# **End of Module**
#
# You have reached the end of this module. If you have any questions, please reach out to your peers using the discussion boards.
#
# If you and your peers are unable to come to a suitable conclusion, do not hesitate to reach out to
# your instructor on the designated discussion board.
#
# When you are comfortable with the content, and have practiced to your satisfaction, you may
# proceed to any related assignments, and to the next module.

# %% [markdown]
# # References

# %% [markdown]
#   - Adhikari, R., & Agrawal, R.K. (2013). An Introductory Study on Time Series Modeling and Forecasting. Lambert Academic Publishing, Germany. Retrieved Dec 14, 2018 from https://arxiv.org/pdf/1302.6613.pdf
#
#
#   - De Gooijer, J.G. & Hyndman, R.J. (2006). 25 years of time series forecasting. International Journal of Forecasting, 22(3), 443-473. Retrieved on Oct 25, 2018 from https://robjhyndman.com/papers/ijf25.pdf
#
#
#   - Moving Average, (n.d). Retrieved from Wikipedia on Oct 25, 2018 from https://en.wikipedia.org/wiki/Moving_average
#
#
#   - Sandgren, N., & Stoica, P. (2006). On Moving Average Parameter Estimation. Department of Information Technology, Uppsala University. Retrieved on Oct 25, 2018 from https://www.it.uu.se/research/publications/reports/2006-022/2006-022-nc.pdf
#
#
#   - Statsmodel developers and others (2012). Statsmodels. Retrieved Dec 14, 2018 from https://devdocs.io/statsmodels/
